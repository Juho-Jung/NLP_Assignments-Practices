# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.corpus import brown
brown_news_tagged =brown.tagged_words(categories='news',
tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in
brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)
for (a,b) in word_tag_pairs:
  print(a,b)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ('Estimates', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ("city's", 'NOUN')
# ("city's", 'NOUN') ('loss', 'NOUN')
# ('loss', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('$344,000', 'NOUN')
# ('$344,000', 'NOUN') ('job', 'NOUN')
# ('job', 'NOUN') ('have', 'VERB')
# ('have', 'VERB') ('ranged', 'VERB')
# ('ranged', 'VERB') ('as', 'ADV')
# ('as', 'ADV') ('high', 'ADJ')
# ('high', 'ADJ') ('as', 'ADP')
# ('as', 'ADP') ('$200,000', 'NOUN')
# ('$200,000', 'NOUN') ('.', '.')
# ('.', '.') ('Shortcuts', 'NOUN')
# ('Shortcuts', 'NOUN') ('unnoticed', 'ADJ')
# ('unnoticed', 'ADJ') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('that', 'ADP')
# ('that', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('Steel', 'NOUN')
# ('Steel', 'NOUN') ('Erection', 'NOUN')
# ('Erection', 'NOUN') ('Co.', 'NOUN')
# ('Co.', 'NOUN') ('contracted', 'VERB')
# ('contracted', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('do', 'VERB')
# ('do', 'VERB') ('the', 'DET')
# ('the', 'DET') ('work', 'NOUN')
# ('work', 'NOUN') ('at', 'ADP')
# ('at', 'ADP') ('an', 'DET')
# ('an', 'DET') ('impossibly', 'ADV')
# ('impossibly', 'ADV') ('low', 'ADJ')
# ('low', 'ADJ') ('cost', 'NOUN')
# ('cost', 'NOUN') ('with', 'ADP')
# ('with', 'ADP') ('a', 'DET')
# ('a', 'DET') ('bid', 'NOUN')
# ('bid', 'NOUN') ('that', 'PRON')
# ('that', 'PRON') ('was', 'VERB')
# ('was', 'VERB') ('far', 'ADV')
# ('far', 'ADV') ('less', 'ADJ')
# ('less', 'ADJ') ('than', 'ADP')
# ('than', 'ADP') ('the', 'DET')
# ('the', 'DET') ('``', '.')
# ('``', '.') ('legitimate', 'ADJ')
# ('legitimate', 'ADJ') ("''", '.')
# ("''", '.') ('bids', 'NOUN')
# ('bids', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('competing', 'VERB')
# ('competing', 'VERB') ('contractors', 'NOUN')
# ('contractors', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('concern', 'NOUN')
# ('concern', 'NOUN') ('then', 'ADV')
# ('then', 'ADV') ('took', 'VERB')
# ('took', 'VERB') ('``', '.')
# ('``', '.') ('shortcuts', 'NOUN')
# ('shortcuts', 'NOUN') ("''", '.')
# ("''", '.') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('project', 'NOUN')
# ('project', 'NOUN') ('but', 'CONJ')
# ('but', 'CONJ') ('got', 'VERB')
# ('got', 'VERB') ('paid', 'VERB')
# ('paid', 'VERB') ('anyway', 'ADV')
# ('anyway', 'ADV') (',', '.')
# (',', '.') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ("Controller's", 'NOUN')
# ("Controller's", 'NOUN') ('charge', 'NOUN')
# ('charge', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('rigging', 'VERB')
# ('rigging', 'VERB') ('was', 'VERB')
# ('was', 'VERB') ('the', 'DET')
# ('the', 'DET') ('latest', 'ADJ')
# ('latest', 'ADJ') ('development', 'NOUN')
# ('development', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('an', 'DET')
# ('an', 'DET') ('investigation', 'NOUN')
# ('investigation', 'NOUN') ('which', 'DET')
# ('which', 'DET') ('also', 'ADV')
# ('also', 'ADV') ('brought', 'VERB')
# ('brought', 'VERB') ('these', 'DET')
# ('these', 'DET') ('disclosures', 'NOUN')
# ('disclosures', 'NOUN') ('Tuesday', 'NOUN')
# ('Tuesday', 'NOUN') (':', '.')
# (':', '.') ('The', 'DET')
# ('The', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('has', 'VERB')
# ('has', 'VERB') ('sued', 'VERB')
# ('sued', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('full', 'ADJ')
# ('full', 'ADJ') ('amount', 'NOUN')
# ('amount', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('$172,400', 'NOUN')
# ('$172,400', 'NOUN') ('performance', 'NOUN')
# ('performance', 'NOUN') ('bond', 'NOUN')
# ('bond', 'NOUN') ('covering', 'VERB')
# ('covering', 'VERB') ('the', 'DET')
# ('the', 'DET') ('contract', 'NOUN')
# ('contract', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('Philadelphia', 'NOUN')
# ('Philadelphia', 'NOUN') ('Transportation', 'NOUN')
# ('Transportation', 'NOUN') ('Co.', 'NOUN')
# ('Co.', 'NOUN') ('is', 'VERB')
# ('is', 'VERB') ('investigating', 'VERB')
# ('investigating', 'VERB') ('the', 'DET')
# ('the', 'DET') ('part', 'NOUN')
# ('part', 'NOUN') ('its', 'DET')
# ('its', 'DET') ('organization', 'NOUN')
# ('organization', 'NOUN') ('played', 'VERB')
# ('played', 'VERB') ('in', 'ADP')
# ('in', 'ADP') ('reviewing', 'VERB')
# ('reviewing', 'VERB') ('the', 'DET')
# ('the', 'DET') ('project', 'NOUN')
# ('project', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('signature', 'NOUN')
# ('signature', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('Harold', 'NOUN')
# ('Harold', 'NOUN') ('V.', 'NOUN')
# ('V.', 'NOUN') ('Varani', 'NOUN')
# ('Varani', 'NOUN') (',', '.')
# (',', '.') ('former', 'ADJ')
# ('former', 'ADJ') ('director', 'NOUN')
# ('director', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('architecture', 'NOUN')
# ('architecture', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('engineering', 'NOUN')
# ('engineering', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Department', 'NOUN')
# ('Department', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('Public', 'ADJ')
# ('Public', 'ADJ') ('Property', 'NOUN')
# ('Property', 'NOUN') (',', '.')
# (',', '.') ('appeared', 'VERB')
# ('appeared', 'VERB') ('on', 'ADP')
# ('on', 'ADP') ('payment', 'NOUN')
# ('payment', 'NOUN') ('vouchers', 'NOUN')
# ('vouchers', 'NOUN') ('certifying', 'VERB')
# ('certifying', 'VERB') ('work', 'NOUN')
# ('work', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('project', 'NOUN')
# ('project', 'NOUN') ('.', '.')
# ('.', '.') ('Varani', 'NOUN')
# ('Varani', 'NOUN') ('has', 'VERB')
# ('has', 'VERB') ('been', 'VERB')
# ('been', 'VERB') ('fired', 'VERB')
# ('fired', 'VERB') ('on', 'ADP')
# ('on', 'ADP') ('charges', 'NOUN')
# ('charges', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('accepting', 'VERB')
# ('accepting', 'VERB') ('gifts', 'NOUN')
# ('gifts', 'NOUN') ('from', 'ADP')
# ('from', 'ADP') ('the', 'DET')
# ('the', 'DET') ('contractor', 'NOUN')
# ('contractor', 'NOUN') ('.', '.')
# ('.', '.') ('Managing', 'VERB')
# ('Managing', 'VERB') ('Director', 'NOUN')
# ('Director', 'NOUN') ('Donald', 'NOUN')
# ('Donald', 'NOUN') ('C.', 'NOUN')
# ('C.', 'NOUN') ('Wagner', 'NOUN')
# ('Wagner', 'NOUN') ('has', 'VERB')
# ('has', 'VERB') ('agreed', 'VERB')
# ('agreed', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('cooperate', 'VERB')
# ('cooperate', 'VERB') ('fully', 'ADV')
# ('fully', 'ADV') ('with', 'ADP')
# ('with', 'ADP') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('after', 'ADP')
# ('after', 'ADP') ('a', 'DET')
# ('a', 'DET') ('period', 'NOUN')
# ('period', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('sharp', 'ADJ')
# ('sharp', 'ADJ') ('disagreement', 'NOUN')
# ('disagreement', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('matter', 'NOUN')
# ('matter', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('announcement', 'NOUN')
# ('announcement', 'NOUN') ('that', 'ADP')
# ('that', 'ADP') ('the', 'DET')
# ('the', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('would', 'VERB')
# ('would', 'VERB') ('sue', 'VERB')
# ('sue', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('recovery', 'NOUN')
# ('recovery', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('performance', 'NOUN')
# ('performance', 'NOUN') ('bond', 'NOUN')
# ('bond', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('made', 'VERB')
# ('made', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('City', 'NOUN')
# ('City', 'NOUN') ('Solicitor', 'NOUN')
# ('Solicitor', 'NOUN') ('David', 'NOUN')
# ('David', 'NOUN') ('Berger', 'NOUN')
# ('Berger', 'NOUN') ('at', 'ADP')
# ('at', 'ADP') ('a', 'DET')
# ('a', 'DET') ('press', 'NOUN')
# ('press', 'NOUN') ('conference', 'NOUN')
# ('conference', 'NOUN') ('following', 'VERB')
# ('following', 'VERB') ('a', 'DET')
# ('a', 'DET') ('meeting', 'NOUN')
# ('meeting', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('morning', 'NOUN')
# ('morning', 'NOUN') ('with', 'ADP')
# ('with', 'ADP') ('Wagner', 'NOUN')
# ('Wagner', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('other', 'ADJ')
# ('other', 'ADJ') ('officials', 'NOUN')
# ('officials', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('the', 'DET')
# ('the', 'DET') ('PTC', 'NOUN')
# ('PTC', 'NOUN') ('as', 'ADV')
# ('as', 'ADV') ('well', 'ADV')
# ('well', 'ADV') ('as', 'ADP')
# ('as', 'ADP') ('representatives', 'NOUN')
# ('representatives', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('an', 'DET')
# ('an', 'DET') ('engineering', 'NOUN')
# ('engineering', 'NOUN') ('firm', 'NOUN')
# ('firm', 'NOUN') ('that', 'DET')
# ('that', 'DET') ('was', 'VERB')
# ('was', 'VERB') ('pulled', 'VERB')
# ('pulled', 'VERB') ('off', 'ADP')
# ('off', 'ADP') ('the', 'DET')
# ('the', 'DET') ('El', 'NOUN')
# ('El', 'NOUN') ('project', 'NOUN')
# ('project', 'NOUN') ('before', 'ADP')
# ('before', 'ADP') ('its', 'DET')
# ('its', 'DET') ('completion', 'NOUN')
# ('completion', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('1959', 'NUM')
# ('1959', 'NUM') ('.', '.')
# ('.', '.') ('Concern', 'NOUN')
# ('Concern', 'NOUN') ('bankrupt', 'ADJ')
# ('bankrupt', 'ADJ') ('The', 'DET')
# ('The', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('company', 'NOUN')
# ('company', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('the', 'DET')
# ('the', 'DET') ('Consolidated', 'VERB')
# ('Consolidated', 'VERB') ('Industries', 'NOUN')
# ('Industries', 'NOUN') (',', '.')
# (',', '.') ('Inc.', 'VERB')
# ('Inc.', 'VERB') (',', '.')
# (',', '.') ('both', 'DET')
# ('both', 'DET') ('of', 'ADP')
# ('of', 'ADP') ('3646', 'NUM')
# ('3646', 'NUM') ('N.', 'ADJ')
# ('N.', 'ADJ') ('2d', 'ADJ')
# ('2d', 'ADJ') ('St.', 'NOUN')
# ('St.', 'NOUN') (',', '.')
# (',', '.') ('filed', 'VERB')
# ('filed', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('reorganization', 'NOUN')
# ('reorganization', 'NOUN') ('under', 'ADP')
# ('under', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Federal', 'ADJ')
# ('Federal', 'ADJ') ('bankruptcy', 'NOUN')
# ('bankruptcy', 'NOUN') ('law', 'NOUN')
# ('law', 'NOUN') ('.', '.')
# ('.', '.') ('On', 'ADP')
# ('On', 'ADP') ('Monday', 'NOUN')
# ('Monday', 'NOUN') (',', '.')
# (',', '.') ('the', 'DET')
# ('the', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('concern', 'NOUN')
# ('concern', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('formally', 'ADV')
# ('formally', 'ADV') ('declared', 'VERB')
# ('declared', 'VERB') ('bankrupt', 'ADJ')
# ('bankrupt', 'ADJ') ('after', 'ADP')
# ('after', 'ADP') ('its', 'DET')
# ('its', 'DET') ('directors', 'NOUN')
# ('directors', 'NOUN') ('indicated', 'VERB')
# ('indicated', 'VERB') ('they', 'PRON')
# ('they', 'PRON') ('could', 'VERB')
# ('could', 'VERB') ('not', 'ADV')
# ('not', 'ADV') ('draw', 'VERB')
# ('draw', 'VERB') ('up', 'PRT')
# ('up', 'PRT') ('a', 'DET')
# ('a', 'DET') ('plan', 'NOUN')
# ('plan', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('reorganization', 'NOUN')
# ('reorganization', 'NOUN') ('.', '.')
# ('.', '.') ('Business', 'NOUN')
# ('Business', 'NOUN') ('relations', 'NOUN')
# ('relations', 'NOUN') ('between', 'ADP')
# ('between', 'ADP') ('the', 'DET')
# ('the', 'DET') ('companies', 'NOUN')
# ('companies', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('city', 'NOUN')
# ('city', 'NOUN') ('have', 'VERB')
# ('have', 'VERB') ('been', 'VERB')
# ('been', 'VERB') ('under', 'ADP')
# ('under', 'ADP') ('investigation', 'NOUN')
# ('investigation', 'NOUN') ('by', 'ADP')
# ('by', 'ADP') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('District', 'NOUN')
# ('District', 'NOUN') ('Attorney', 'NOUN')
# ('Attorney', 'NOUN') ('James', 'NOUN')
# ('James', 'NOUN') ('C.', 'NOUN')
# ('C.', 'NOUN') ('Crumlish', 'NOUN')
# ('Crumlish', 'NOUN') (',', '.')
# (',', '.') ('Jr.', 'NOUN')
# ('Jr.', 'NOUN') ('.', '.')
# ('.', '.') ('Intervenes', 'VERB')
# ('Intervenes', 'VERB') ('in', 'ADP')
# ('in', 'ADP') ('case', 'NOUN')
# ('case', 'NOUN') ('The', 'DET')
# ('The', 'DET') ('suit', 'NOUN')
# ('suit', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('filed', 'VERB')
# ('filed', 'VERB') ('later', 'ADV')
# ('later', 'ADV') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('day', 'NOUN')
# ('day', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('Common', 'ADJ')
# ('Common', 'ADJ') ('Pleas', 'NOUN')
# ('Pleas', 'NOUN') ('Court', 'NOUN')
# ('Court', 'NOUN') ('7', 'NUM')
# ('7', 'NUM') ('against', 'ADP')
# ('against', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('company', 'NOUN')
# ('company', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('two', 'NUM')
# ('two', 'NUM') ('bonding', 'VERB')
# ('bonding', 'VERB') ('firms', 'NOUN')
# ('firms', 'NOUN') ('.', '.')
# ('.', '.') ('Travelers', 'NOUN')
# ('Travelers', 'NOUN') ('Indemnity', 'NOUN')
# ('Indemnity', 'NOUN') ('Co.', 'NOUN')
# ('Co.', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('the', 'DET')
# ('the', 'DET') ('Continental', 'ADJ')
# ('Continental', 'ADJ') ('Casualty', 'NOUN')
# ('Casualty', 'NOUN') ('Co.', 'NOUN')
# ('Co.', 'NOUN') ('.', '.')
# ('.', '.') ('At', 'ADP')
# ('At', 'ADP') ("Berger's", 'NOUN')
# ("Berger's", 'NOUN') ('direction', 'NOUN')
# ('direction', 'NOUN') (',', '.')
# (',', '.') ('the', 'DET')
# ('the', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('also', 'ADV')
# ('also', 'ADV') ('intervened', 'VERB')
# ('intervened', 'VERB') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('bankruptcy', 'NOUN')
# ('bankruptcy', 'NOUN') ('case', 'NOUN')
# ('case', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('U.', 'NOUN')
# ('U.', 'NOUN') ('S.', 'NOUN')
# ('S.', 'NOUN') ('District', 'NOUN')
# ('District', 'NOUN') ('Court', 'NOUN')
# ('Court', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('a', 'DET')
# ('a', 'DET') ('move', 'NOUN')
# ('move', 'NOUN') ('preliminary', 'ADJ')
# ('preliminary', 'ADJ') ('to', 'ADP')
# ('to', 'ADP') ('filing', 'VERB')
# ('filing', 'VERB') ('a', 'DET')
# ('a', 'DET') ('claim', 'NOUN')
# ('claim', 'NOUN') ('there', 'ADV')
# ('there', 'ADV') ('.', '.')
# ('.', '.') ('``', '.')
# ('``', '.') ('I', 'PRON')
# ('I', 'PRON') ('am', 'VERB')
# ('am', 'VERB') ('taking', 'VERB')
# ('taking', 'VERB') ('the', 'DET')
# ('the', 'DET') ('position', 'NOUN')
# ('position', 'NOUN') ('that', 'ADP')
# ('that', 'ADP') ('the', 'DET')
# ('the', 'DET') ('contract', 'NOUN')
# ('contract', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('clearly', 'ADV')
# ('clearly', 'ADV') ('violated', 'VERB')
# ('violated', 'VERB') ("''", '.')
# ("''", '.') (',', '.')
# (',', '.') ('Berger', 'NOUN')
# ('Berger', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('contract', 'NOUN')
# ('contract', 'NOUN') ('violations', 'NOUN')
# ('violations', 'NOUN') ('mostly', 'ADV')
# ('mostly', 'ADV') ('involve', 'VERB')
# ('involve', 'VERB') ('failure', 'NOUN')
# ('failure', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('perform', 'VERB')
# ('perform', 'VERB') ('rehabilitation', 'NOUN')
# ('rehabilitation', 'NOUN') ('work', 'NOUN')
# ('work', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('expansion', 'NOUN')
# ('expansion', 'NOUN') ('joints', 'NOUN')
# ('joints', 'NOUN') ('along', 'ADP')
# ('along', 'ADP') ('the', 'DET')
# ('the', 'DET') ('El', 'NOUN')
# ('El', 'NOUN') ('track', 'NOUN')
# ('track', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('contract', 'NOUN')
# ('contract', 'NOUN') ('called', 'VERB')
# ('called', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('overhauling', 'NOUN')
# ('overhauling', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('102', 'NUM')
# ('102', 'NUM') ('joints', 'NOUN')
# ('joints', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('paid', 'VERB')
# ('paid', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('work', 'NOUN')
# ('work', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('75', 'NUM')
# ('75', 'NUM') (',', '.')
# (',', '.') ('of', 'ADP')
# ('of', 'ADP') ('which', 'DET')
# ('which', 'DET') ('no', 'DET')
# ('no', 'DET') ('more', 'ADJ')
# ('more', 'ADJ') ('than', 'ADP')
# ('than', 'ADP') ('21', 'NUM')
# ('21', 'NUM') ('were', 'VERB')
# ('were', 'VERB') ('repaired', 'VERB')
# ('repaired', 'VERB') (',', '.')
# (',', '.') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('charged', 'VERB')
# ('charged', 'VERB') ('.', '.')
# ('.', '.') ('Wide', 'ADJ')
# ('Wide', 'ADJ') ('range', 'NOUN')
# ('range', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('bids', 'NOUN')
# ('bids', 'NOUN') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('the', 'DET')
# ('the', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('concern', 'NOUN')
# ('concern', 'NOUN') ('contracted', 'VERB')
# ('contracted', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('do', 'VERB')
# ('do', 'VERB') ('the', 'DET')
# ('the', 'DET') ('repairs', 'NOUN')
# ('repairs', 'NOUN') ('at', 'ADP')
# ('at', 'ADP') ('a', 'DET')
# ('a', 'DET') ('cost', 'NOUN')
# ('cost', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('$500', 'NOUN')
# ('$500', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('each', 'DET')
# ('each', 'DET') ('joint', 'NOUN')
# ('joint', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('bid', 'NOUN')
# ('bid', 'NOUN') ('from', 'ADP')
# ('from', 'ADP') ('A.', 'NOUN')
# ('A.', 'NOUN') ('Belanger', 'NOUN')
# ('Belanger', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Sons', 'NOUN')
# ('Sons', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('Cambridge', 'NOUN')
# ('Cambridge', 'NOUN') (',', '.')
# (',', '.') ('Mass.', 'NOUN')
# ('Mass.', 'NOUN') (',', '.')
# (',', '.') ('which', 'DET')
# ('which', 'DET') ('listed', 'VERB')
# ('listed', 'VERB') ('the', 'DET')
# ('the', 'DET') ('same', 'ADJ')
# ('same', 'ADJ') ('officers', 'NOUN')
# ('officers', 'NOUN') ('as', 'ADP')
# ('as', 'ADP') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') (',', '.')
# (',', '.') ('was', 'VERB')
# ('was', 'VERB') ('$600', 'NOUN')
# ('$600', 'NOUN') ('per', 'ADP')
# ('per', 'ADP') ('joint', 'NOUN')
# ('joint', 'NOUN') ('.', '.')
# ('.', '.') ('But', 'CONJ')
# ('But', 'CONJ') (',', '.')
# (',', '.') ('Hemphill', 'NOUN')
# ('Hemphill', 'NOUN') ('added', 'VERB')
# ('added', 'VERB') (',', '.')
# (',', '.') ('bids', 'NOUN')
# ('bids', 'NOUN') ('from', 'ADP')
# ('from', 'ADP') ('other', 'ADJ')
# ('other', 'ADJ') ('contractors', 'NOUN')
# ('contractors', 'NOUN') ('ranged', 'VERB')
# ('ranged', 'VERB') ('from', 'ADP')
# ('from', 'ADP') ('$2400', 'NOUN')
# ('$2400', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('$3100', 'NOUN')
# ('$3100', 'NOUN') ('per', 'ADP')
# ('per', 'ADP') ('joint', 'NOUN')
# ('joint', 'NOUN') ('.', '.')
# ('.', '.') ("Berger's", 'NOUN')
# ("Berger's", 'NOUN') ('decision', 'NOUN')
# ('decision', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('sue', 'VERB')
# ('sue', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('full', 'ADV')
# ('full', 'ADV') ('amount', 'VERB')
# ('amount', 'VERB') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('performance', 'NOUN')
# ('performance', 'NOUN') ('bond', 'NOUN')
# ('bond', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('questioned', 'VERB')
# ('questioned', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('Wagner', 'NOUN')
# ('Wagner', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('morning', 'NOUN')
# ('morning', 'NOUN') ('press', 'NOUN')
# ('press', 'NOUN') ('conference', 'NOUN')
# ('conference', 'NOUN') ('.', '.')
# ('.', '.') ('Wagner', 'NOUN')
# ('Wagner', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('the', 'DET')
# ('the', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('paid', 'VERB')
# ('paid', 'VERB') ('only', 'ADV')
# ('only', 'ADV') ('$37,500', 'NOUN')
# ('$37,500', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Hughes', 'NOUN')
# ('Hughes', 'NOUN') ('company', 'NOUN')
# ('company', 'NOUN') ('.', '.')
# ('.', '.') ('``', '.')
# ('``', '.') ('We', 'PRON')
# ('We', 'PRON') ("won't", 'VERB')
# ("won't", 'VERB') ('know', 'VERB')
# ('know', 'VERB') ('the', 'DET')
# ('the', 'DET') ('full', 'ADJ')
# ('full', 'ADJ') ('amount', 'NOUN')
# ('amount', 'NOUN') ('until', 'ADP')
# ('until', 'ADP') ('we', 'PRON')
# ('we', 'PRON') ('get', 'VERB')
# ('get', 'VERB') ('a', 'DET')
# ('a', 'DET') ('full', 'ADJ')
# ('full', 'ADJ') ('report', 'NOUN')
# ('report', 'NOUN') ("''", '.')
# ("''", '.') (',', '.')
# (',', '.') ('Wagner', 'NOUN')
# ('Wagner', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('``', '.')
# ('``', '.') ('We', 'PRON')
# ('We', 'PRON') ('can', 'VERB')
# ('can', 'VERB') ('claim', 'VERB')
# ('claim', 'VERB') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('maximum', 'ADJ')
# ('maximum', 'ADJ') ('amount', 'NOUN')
# ('amount', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('bond', 'NOUN')
# ('bond', 'NOUN') ("''", '.')
# ("''", '.') (',', '.')
# (',', '.') ('Berger', 'NOUN')
# ('Berger', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('Wagner', 'NOUN')
# ('Wagner', 'NOUN') ('replied', 'VERB')
# ('replied', 'VERB') (',', '.')
# (',', '.') ('``', '.')
# ('``', '.') ("Can't", 'VERB')
# ("Can't", 'VERB') ('you', 'PRON')
# ('you', 'PRON') ('just', 'ADV')
# ('just', 'ADV') ('see', 'VERB')
# ('see', 'VERB') ('the', 'DET')
# ('the', 'DET') ('headline', 'NOUN')
# ('headline', 'NOUN') (':', '.')
# (':', '.') ("'", '.')
# ("'", '.') ('City', 'NOUN')
# ('City', 'NOUN') ('Hooked', 'VERB')
# ('Hooked', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('$172,000', 'NOUN')
# ('$172,000', 'NOUN') ("'", '.')
# ("'", '.') ("''", '.')
# ("''", '.') ('?', '.')
# ('?', '.') ('?', '.')
# ('?', '.') ("'", '.')
# ("'", '.') ('know', 'VERB')
# ('know', 'VERB') ('enough', 'ADJ')
# ('enough', 'ADJ') ('to', 'PRT')
# ('to', 'PRT') ('sue', 'VERB')
# ('sue', 'VERB') ("'", '.')
# ("'", '.') ('Berger', 'NOUN')
# ('Berger', 'NOUN') ('insisted', 'VERB')
# ('insisted', 'VERB') ('that', 'ADP')
# ('that', 'ADP') ('``', '.')
# ('``', '.') ('we', 'PRON')
# ('we', 'PRON') ('know', 'VERB')
# ('know', 'VERB') ('enough', 'ADJ')
# ('enough', 'ADJ') ('to', 'PRT')
# ('to', 'PRT') ('sue', 'VERB')
# ('sue', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('full', 'ADJ')
# ('full', 'ADJ') ('amount', 'NOUN')
# ('amount', 'NOUN') ("''", '.')
# ("''", '.') ('.', '.')
# ('.', '.') ('Douglas', 'NOUN')
# ('Douglas', 'NOUN') ('M.', 'NOUN')
# ('M.', 'NOUN') ('Pratt', 'NOUN')
# ('Pratt', 'NOUN') (',', '.')
# (',', '.') ('president', 'NOUN')
# ('president', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('PTC', 'NOUN')
# ('PTC', 'NOUN') (',', '.')
# (',', '.') ('who', 'PRON')
# ('who', 'PRON') ('attended', 'VERB')
# ('attended', 'VERB') ('the', 'DET')
# ('the', 'DET') ('meeting', 'NOUN')
# ('meeting', 'NOUN') (',', '.')
# (',', '.') ('said', 'VERB')
# ('said', 'VERB') ('the', 'DET')
# ('the', 'DET') ('transit', 'NOUN')
# ('transit', 'NOUN') ('company', 'NOUN')
# ('company', 'NOUN') ('is', 'VERB')
# ('is', 'VERB') ('reviewing', 'VERB')
# ('reviewing', 'VERB') ('the', 'DET')
# ('the', 'DET') ('work', 'NOUN')
# ('work', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('El', 'NOUN')
# ('El', 'NOUN') ('.', '.')
# ('.', '.') ('``', '.')
# ('``', '.') ('We', 'PRON')
# ('We', 'PRON') ('want', 'VERB')
# ('want', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('find', 'VERB')
# ('find', 'VERB') ('out', 'PRT')
# ('out', 'PRT') ('who', 'PRON')
# ('who', 'PRON') ('knew', 'VERB')
# ('knew', 'VERB') ('about', 'ADP')
# ('about', 'ADP') ('it', 'PRON')
# ('it', 'PRON') ("''", '.')
# ("''", '.') (',', '.')
# (',', '.') ('Pratt', 'NOUN')
# ('Pratt', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('``', '.')
# ('``', '.') ('Certain', 'ADJ')
# ('Certain', 'ADJ') ('people', 'NOUN')
# ('people', 'NOUN') ('must', 'VERB')
# ('must', 'VERB') ('have', 'VERB')
# ('have', 'VERB') ('known', 'VERB')
# ('known', 'VERB') ('about', 'ADP')
# ('about', 'ADP') ('it', 'PRON')
# ('it', 'PRON') ("''", '.')
# ("''", '.') ('.', '.')
# ('.', '.') ('``', '.')
# ('``', '.') ('The', 'DET')
# ('The', 'DET') ('PTC', 'NOUN')
# ('PTC', 'NOUN') ('is', 'VERB')
# ('is', 'VERB') ('investigating', 'VERB')
# ('investigating', 'VERB') ('the', 'DET')
# ('the', 'DET') ('whole', 'ADJ')
# ('whole', 'ADJ') ('matter', 'NOUN')
# ('matter', 'NOUN') ("''", '.')
# ("''", '.') (',', '.')
# (',', '.') ('Pratt', 'NOUN')
# ('Pratt', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('Samuel', 'NOUN')
# ('Samuel', 'NOUN') ('D.', 'NOUN')
# ('D.', 'NOUN') ('Goodis', 'NOUN')
# ('Goodis', 'NOUN') (',', '.')
# (',', '.') ('representing', 'VERB')
# ('representing', 'VERB') ('the', 'DET')
# ('the', 'DET') ('Philadelphia', 'NOUN')
# ('Philadelphia', 'NOUN') ('Hotel', 'NOUN')
# ('Hotel', 'NOUN') ('Association', 'NOUN')
# ('Association', 'NOUN') (',', '.')
# (',', '.') ('objected', 'VERB')
# ('objected', 'VERB') ('on', 'ADP')
# ('on', 'ADP') ('Tuesday', 'NOUN')
# ('Tuesday', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('a', 'DET')
# ('a', 'DET') ('proposed', 'VERB')
# ('proposed', 'VERB') ('boost', 'NOUN')
# ('boost', 'NOUN') ('by', 'ADP')
# ('by', 'ADP') ('the', 'DET')
# ('the', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('licensing', 'VERB')
# ('licensing', 'VERB') ('fees', 'NOUN')
# ('fees', 'NOUN') (',', '.')
# (',', '.') ('saying', 'VERB')
# ('saying', 'VERB') ('that', 'DET')
# ('that', 'DET') ('occupancy', 'NOUN')
# ('occupancy', 'NOUN') ('rates', 'NOUN')
# ('rates', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('major', 'ADJ')
# ('major', 'ADJ') ('hotels', 'NOUN')
# ('hotels', 'NOUN') ('here', 'ADV')
# ('here', 'ADV') ('ranged', 'VERB')
# ('ranged', 'VERB') ('from', 'ADP')
# ('from', 'ADP') ('48', 'NUM')
# ('48', 'NUM') ('to', 'ADP')
# ('to', 'ADP') ('74', 'NUM')
# ('74', 'NUM') ('percent', 'NOUN')
# ('percent', 'NOUN') ('last', 'ADJ')
# ('last', 'ADJ') ('year', 'NOUN')
# ('year', 'NOUN') ('.', '.')
# ('.', '.') ('Goodis', 'NOUN')
# ('Goodis', 'NOUN') ('voiced', 'VERB')
# ('voiced', 'VERB') ('his', 'DET')
# ('his', 'DET') ('objection', 'NOUN')
# ('objection', 'NOUN') ('before', 'ADP')
# ('before', 'ADP') ('City', 'NOUN')
# ('City', 'NOUN') ("Council's", 'NOUN')
# ("Council's", 'NOUN') ('Finance', 'NOUN')
# ('Finance', 'NOUN') ('Committee', 'NOUN')
# ('Committee', 'NOUN') ('.', '.')
# ('.', '.') ('For', 'ADP')
# ('For', 'ADP') ('hotels', 'NOUN')
# ('hotels', 'NOUN') ('with', 'ADP')
# ('with', 'ADP') ('1000', 'NUM')
# ('1000', 'NUM') ('rooms', 'NOUN')
# ('rooms', 'NOUN') (',', '.')
# (',', '.') ('the', 'DET')
# ('the', 'DET') ('increased', 'VERB')
# ('increased', 'VERB') ('license', 'NOUN')
# ('license', 'NOUN') ('fee', 'NOUN')
# ('fee', 'NOUN') ('would', 'VERB')
# ('would', 'VERB') ('mean', 'VERB')
# ('mean', 'VERB') ('an', 'DET')
# ('an', 'DET') ('expense', 'NOUN')
# ('expense', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('$5000', 'NOUN')
# ('$5000', 'NOUN') ('a', 'DET')
# ('a', 'DET') ('year', 'NOUN')
# ('year', 'NOUN') (',', '.')
# (',', '.') ('Goodis', 'NOUN')
# ('Goodis', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('Testifies', 'VERB')
# ('Testifies', 'VERB') ('at', 'ADP')
# ('at', 'ADP') ('hearing', 'NOUN')
# ('hearing', 'NOUN') ('His', 'DET')
# ('His', 'DET') ('testimony', 'NOUN')
# ('testimony', 'NOUN') ('came', 'VERB')
# ('came', 'VERB') ('during', 'ADP')
# ('during', 'ADP') ('a', 'DET')
# ('a', 'DET') ('hearing', 'NOUN')
# ('hearing', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('a', 'DET')
# ('a', 'DET') ('bill', 'NOUN')
# ('bill', 'NOUN') ('raising', 'VERB')
# ('raising', 'VERB') ('fees', 'NOUN')
# ('fees', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('a', 'DET')
# ('a', 'DET') ('wide', 'ADJ')
# ('wide', 'ADJ') ('variety', 'NOUN')
# ('variety', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('licenses', 'NOUN')
# ('licenses', 'NOUN') (',', '.')
# (',', '.') ('permits', 'NOUN')
# ('permits', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('city', 'NOUN')
# ('city', 'NOUN') ('services', 'NOUN')
# ('services', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('new', 'ADJ')
# ('new', 'ADJ') ('fees', 'NOUN')
# ('fees', 'NOUN') ('are', 'VERB')
# ('are', 'VERB') ('expected', 'VERB')
# ('expected', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('raise', 'VERB')
# ('raise', 'VERB') ('an', 'DET')
# ('an', 'DET') ('additional', 'ADJ')
# ('additional', 'ADJ') ('$740,000', 'NOUN')
# ('$740,000', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('remainder', 'NOUN')
# ('remainder', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('1961', 'NUM')
# ('1961', 'NUM') ('and', 'CONJ')
# ('and', 'CONJ') ('$2,330,000', 'NOUN')
# ('$2,330,000', 'NOUN') ('more', 'ADJ')
# ('more', 'ADJ') ('a', 'DET')
# ('a', 'DET') ('year', 'NOUN')
# ('year', 'NOUN') ('after', 'ADP')
# ('after', 'ADP') ('that', 'DET')
# ('that', 'DET') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('ordinance', 'NOUN')
# ('ordinance', 'NOUN') ('would', 'VERB')
# ('would', 'VERB') ('increase', 'VERB')
# ('increase', 'VERB') ('the', 'DET')
# ('the', 'DET') ('fee', 'NOUN')
# ('fee', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('rooming', 'VERB')
# ('rooming', 'VERB') ('houses', 'NOUN')
# ('houses', 'NOUN') (',', '.')
# (',', '.') ('hotels', 'NOUN')
# ('hotels', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('multi-family', 'ADJ')
# ('multi-family', 'ADJ') ('dwellings', 'NOUN')
# ('dwellings', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('$5', 'NOUN')
# ('$5', 'NOUN') ('a', 'DET')
# ('a', 'DET') ('room', 'NOUN')
# ('room', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('cost', 'NOUN')
# ('cost', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('a', 'DET')
# ('a', 'DET') ('license', 'NOUN')
# ('license', 'NOUN') ('now', 'ADV')
# ('now', 'ADV') ('is', 'VERB')
# ('is', 'VERB') ('$2', 'NOUN')
# ('$2', 'NOUN') (',', '.')
# (',', '.') ('with', 'ADP')
# ('with', 'ADP') ('an', 'DET')
# ('an', 'DET') ('annual', 'ADJ')
# ('annual', 'ADJ') ('renewal', 'NOUN')
# ('renewal', 'NOUN') ('fee', 'NOUN')
# ('fee', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('$1', 'NOUN')
# ('$1', 'NOUN') ('.', '.')
# ('.', '.') ('Goodis', 'NOUN')
# ('Goodis', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('that', 'ADP')
# ('that', 'ADP') ('single', 'ADJ')
# ('single', 'ADJ') ('rooms', 'NOUN')
# ('rooms', 'NOUN') ('account', 'VERB')
# ('account', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('95', 'NUM')
# ('95', 'NUM') ('percent', 'NOUN')
# ('percent', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('accomodations', 'NOUN')
# ('accomodations', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('some', 'DET')
# ('some', 'DET') ('hotels', 'NOUN')
# ('hotels', 'NOUN') ('.', '.')
# ('.', '.') ('Revenue', 'NOUN')
# ('Revenue', 'NOUN') ('estimated', 'VERB')
# ('estimated', 'VERB') ('The', 'DET')
# ('The', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('expects', 'VERB')
# ('expects', 'VERB') ('the', 'DET')
# ('the', 'DET') ('higher', 'ADJ')
# ('higher', 'ADJ') ('rooming', 'VERB')
# ('rooming', 'VERB') ('house', 'NOUN')
# ('house', 'NOUN') (',', '.')
# (',', '.') ('hotel', 'NOUN')
# ('hotel', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('apartment', 'NOUN')
# ('apartment', 'NOUN') ('house', 'NOUN')
# ('house', 'NOUN') ('fees', 'NOUN')
# ('fees', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('bring', 'VERB')
# ('bring', 'VERB') ('in', 'PRT')
# ('in', 'PRT') ('an', 'DET')
# ('an', 'DET') ('additional', 'ADJ')
# ('additional', 'ADJ') ('$457,000', 'NOUN')
# ('$457,000', 'NOUN') ('a', 'DET')
# ('a', 'DET') ('year', 'NOUN')
# ('year', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('increase', 'NOUN')
# ('increase', 'NOUN') ('also', 'ADV')
# ('also', 'ADV') ('was', 'VERB')
# ('was', 'VERB') ('opposed', 'VERB')
# ('opposed', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('Leonard', 'NOUN')
# ('Leonard', 'NOUN') ('Kaplan', 'NOUN')
# ('Kaplan', 'NOUN') (',', '.')
# (',', '.') ('spokesman', 'NOUN')
# ('spokesman', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Home', 'NOUN')
# ('Home', 'NOUN') ('Builders', 'NOUN')
# ('Builders', 'NOUN') ('Association', 'NOUN')
# ('Association', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('Philadelphia', 'NOUN')
# ('Philadelphia', 'NOUN') (',', '.')
# (',', '.') ('on', 'ADP')
# ('on', 'ADP') ('behalf', 'NOUN')
# ('behalf', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('association', 'NOUN')
# ('association', 'NOUN') ('members', 'NOUN')
# ('members', 'NOUN') ('who', 'PRON')
# ('who', 'PRON') ('operate', 'VERB')
# ('operate', 'VERB') ('apartment', 'NOUN')
# ('apartment', 'NOUN') ('houses', 'NOUN')
# ('houses', 'NOUN') ('.', '.')
# ('.', '.') ('A', 'DET')
# ('A', 'DET') ('proposal', 'NOUN')
# ('proposal', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('raise', 'VERB')
# ('raise', 'VERB') ('dog', 'NOUN')
# ('dog', 'NOUN') ('license', 'NOUN')
# ('license', 'NOUN') ('fees', 'NOUN')
# ('fees', 'NOUN') ('drew', 'VERB')
# ('drew', 'VERB') ('an', 'DET')
# ('an', 'DET') ('objection', 'NOUN')
# ('objection', 'NOUN') ('from', 'ADP')
# ('from', 'ADP') ('Councilwoman', 'NOUN')
# ('Councilwoman', 'NOUN') ('Virginia', 'NOUN')
# ('Virginia', 'NOUN') ('Knauer', 'NOUN')
# ('Knauer', 'NOUN') (',', '.')
# (',', '.') ('who', 'PRON')
# ('who', 'PRON') ('formerly', 'ADV')
# ('formerly', 'ADV') ('raised', 'VERB')
# ('raised', 'VERB') ('pedigreed', 'ADJ')
# ('pedigreed', 'ADJ') ('dogs', 'NOUN')
# ('dogs', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('ordinance', 'NOUN')
# ('ordinance', 'NOUN') ('would', 'VERB')
# ('would', 'VERB') ('increase', 'VERB')
# ('increase', 'VERB') ('fees', 'NOUN')
# ('fees', 'NOUN') ('from', 'ADP')
# ('from', 'ADP') ('$1', 'NOUN')
# ('$1', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('males', 'NOUN')
# ('males', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('$2', 'NOUN')
# ('$2', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('females', 'NOUN')
# ('females', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('a', 'DET')
# ('a', 'DET') ('flat', 'ADJ')
# ('flat', 'ADJ') ('$5', 'NOUN')
# ('$5', 'NOUN') ('a', 'DET')
# ('a', 'DET') ('dog', 'NOUN')
# ('dog', 'NOUN') ('.', '.')
# ('.', '.') ('Commissioner', 'NOUN')
# ('Commissioner', 'NOUN') ('replies', 'VERB')
# ('replies', 'VERB') ('Mrs.', 'NOUN')
# ('Mrs.', 'NOUN') ('Knauer', 'NOUN')
# ('Knauer', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('she', 'PRON')
# ('she', 'PRON') ('did', 'VERB')
# ('did', 'VERB') ('not', 'ADV')
# ('not', 'ADV') ('think', 'VERB')
# ('think', 'VERB') ('dog', 'NOUN')
# ('dog', 'NOUN') ('owners', 'NOUN')
# ('owners', 'NOUN') ('should', 'VERB')
# ('should', 'VERB') ('be', 'VERB')
# ('be', 'VERB') ('penalized', 'VERB')
# ('penalized', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ("city's", 'NOUN')
# ("city's", 'NOUN') ('services', 'NOUN')
# ('services', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('animal', 'NOUN')
# ('animal', 'NOUN') ('care', 'NOUN')
# ('care', 'NOUN') ('.', '.')
# ('.', '.') ('In', 'ADP')
# ('In', 'ADP') ('reply', 'NOUN')
# ('reply', 'NOUN') (',', '.')
# (',', '.') ('Deputy', 'ADJ')
# ('Deputy', 'ADJ') ('Police', 'NOUN')
# ('Police', 'NOUN') ('Commissioner', 'NOUN')
# ('Commissioner', 'NOUN') ('Howard', 'NOUN')
# ('Howard', 'NOUN') ('R.', 'NOUN')
# ('R.', 'NOUN') ('Leary', 'NOUN')
# ('Leary', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('that', 'ADP')
# ('that', 'ADP') ('the', 'DET')
# ('the', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('spends', 'VERB')
# ('spends', 'VERB') ('more', 'ADJ')
# ('more', 'ADJ') ('than', 'ADP')
# ('than', 'ADP') ('$115,000', 'NOUN')
# ('$115,000', 'NOUN') ('annually', 'ADV')
# ('annually', 'ADV') ('to', 'PRT')
# ('to', 'PRT') ('license', 'VERB')
# ('license', 'VERB') ('and', 'CONJ')
# ('and', 'CONJ') ('regulate', 'VERB')
# ('regulate', 'VERB') ('dogs', 'NOUN')
# ('dogs', 'NOUN') ('but', 'CONJ')
# ('but', 'CONJ') ('collects', 'VERB')
# ('collects', 'VERB') ('only', 'ADV')
# ('only', 'ADV') ('$43,000', 'NOUN')
# ('$43,000', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('fees', 'NOUN')
# ('fees', 'NOUN') ('.', '.')
# ('.', '.') ('He', 'PRON')
# ('He', 'PRON') ('reported', 'VERB')
# ('reported', 'VERB') ('that', 'ADP')
# ('that', 'ADP') ('the', 'DET')
# ('the', 'DET') ("city's", 'NOUN')
# ("city's", 'NOUN') ('contributions', 'NOUN')
# ('contributions', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('animal', 'NOUN')
# ('animal', 'NOUN') ('care', 'NOUN')
# ('care', 'NOUN') ('included', 'VERB')
# ('included', 'VERB') ('$67,000', 'NOUN')
# ('$67,000', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('the', 'DET')
# ('the', 'DET') ("Women's", 'NOUN')
# ("Women's", 'NOUN') ('S.P.C.A.', 'NOUN')
# ('S.P.C.A.', 'NOUN') (';', '.')
# (';', '.') (';', '.')
# (';', '.') ('$15,000', 'NOUN')
# ('$15,000', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('pay', 'VERB')
# ('pay', 'VERB') ('six', 'NUM')
# ('six', 'NUM') ('policemen', 'NOUN')
# ('policemen', 'NOUN') ('assigned', 'VERB')
# ('assigned', 'VERB') ('as', 'ADP')
# ('as', 'ADP') ('dog', 'NOUN')
# ('dog', 'NOUN') ('catchers', 'NOUN')
# ('catchers', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('$15,000', 'NOUN')
# ('$15,000', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('investigate', 'VERB')
# ('investigate', 'VERB') ('dog', 'NOUN')
# ('dog', 'NOUN') ('bites', 'NOUN')
# ('bites', 'NOUN') ('.', '.')
# ('.', '.') ('Backs', 'VERB')
# ('Backs', 'VERB') ('higher', 'ADJ')
# ('higher', 'ADJ') ('fees', 'NOUN')
# ('fees', 'NOUN') ('City', 'NOUN')
# ('City', 'NOUN') ('Finance', 'NOUN')
# ('Finance', 'NOUN') ('Director', 'NOUN')
# ('Director', 'NOUN') ('Richard', 'NOUN')
# ('Richard', 'NOUN') ('J.', 'NOUN')
# ('J.', 'NOUN') ('McConnell', 'NOUN')
# ('McConnell', 'NOUN') ('indorsed', 'VERB')
# ('indorsed', 'VERB') ('the', 'DET')
# ('the', 'DET') ('higher', 'ADJ')
# ('higher', 'ADJ') ('fees', 'NOUN')
# ('fees', 'NOUN') (',', '.')
# (',', '.') ('which', 'DET')
# ('which', 'DET') (',', '.')
# (',', '.') ('he', 'PRON')
# ('he', 'PRON') ('said', 'VERB')
# ('said', 'VERB') (',', '.')
# (',', '.') ('had', 'VERB')
# ('had', 'VERB') ('been', 'VERB')
# ('been', 'VERB') ('under', 'ADP')
# ('under', 'ADP') ('study', 'NOUN')
# ('study', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('more', 'ADJ')
# ('more', 'ADJ') ('than', 'ADP')
# ('than', 'ADP') ('a', 'DET')
# ('a', 'DET') ('year', 'NOUN')
# ('year', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('city', 'NOUN')
# ('city', 'NOUN') ('is', 'VERB')
# ('is', 'VERB') ('not', 'ADV')
# ('not', 'ADV') ('adequately', 'ADV')
# ('adequately', 'ADV') ('compensated', 'VERB')
# ('compensated', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('services', 'NOUN')
# ('services', 'NOUN') ('covered', 'VERB')
# ('covered', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('the', 'DET')
# ('the', 'DET') ('fees', 'NOUN')
# ('fees', 'NOUN') (',', '.')
# (',', '.') ('he', 'PRON')
# ('he', 'PRON') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('new', 'ADJ')
# ('new', 'ADJ') ('fee', 'NOUN')
# ('fee', 'NOUN') ('schedule', 'NOUN')
# ('schedule', 'NOUN') ('also', 'ADV')
# ('also', 'ADV') ('was', 'VERB')
# ('was', 'VERB') ('supported', 'VERB')
# ('supported', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('Commissioner', 'NOUN')
# ('Commissioner', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('Licenses', 'NOUN')
# ('Licenses', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Inspections', 'NOUN')
# ('Inspections', 'NOUN') ('Barnet', 'NOUN')
# ('Barnet', 'NOUN') ('Lieberman', 'NOUN')
# ('Lieberman', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Health', 'NOUN')
# ('Health', 'NOUN') ('Commissioner', 'NOUN')
# ('Commissioner', 'NOUN') ('Eugene', 'NOUN')
# ('Eugene', 'NOUN') ('A.', 'NOUN')
# ('A.', 'NOUN') ('Gillis', 'NOUN')
# ('Gillis', 'NOUN') ('.', '.')
# ('.', '.') ('Petitions', 'NOUN')
# ('Petitions', 'NOUN') ('asking', 'VERB')
# ('asking', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('a', 'DET')
# ('a', 'DET') ('jail', 'NOUN')
# ('jail', 'NOUN') ('term', 'NOUN')
# ('term', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('Norristown', 'NOUN')
# ('Norristown', 'NOUN') ('attorney', 'NOUN')
# ('attorney', 'NOUN') ('Julian', 'NOUN')
# ('Julian', 'NOUN') ('W.', 'NOUN')
# ('W.', 'NOUN') ('Barnard', 'NOUN')
# ('Barnard', 'NOUN') ('will', 'VERB')
# ('will', 'VERB') ('be', 'VERB')
# ('be', 'VERB') ('presented', 'VERB')
# ('presented', 'VERB') ('to', 'ADP')
# ('to', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Montgomery', 'NOUN')
# ('Montgomery', 'NOUN') ('County', 'NOUN')
# ('County', 'NOUN') ('Court', 'NOUN')
# ('Court', 'NOUN') ('Friday', 'NOUN')
# ('Friday', 'NOUN') (',', '.')
# (',', '.') ('it', 'PRON')
# ('it', 'PRON') ('was', 'VERB')
# ('was', 'VERB') ('disclosed', 'VERB')
# ('disclosed', 'VERB') ('Tuesday', 'NOUN')
# ('Tuesday', 'NOUN') ('by', 'ADP')
# ('by', 'ADP') ('Horace', 'NOUN')
# ('Horace', 'NOUN') ('A.', 'NOUN')
# ('A.', 'NOUN') ('Davenport', 'NOUN')
# ('Davenport', 'NOUN') (',', '.')
# (',', '.') ('counsel', 'NOUN')
# ('counsel', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('widow', 'NOUN')
# ('widow', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('man', 'NOUN')
# ('man', 'NOUN') ('killed', 'VERB')
# ('killed', 'VERB') ('last', 'ADJ')
# ('last', 'ADJ') ('Nov.', 'NOUN')
# ('Nov.', 'NOUN') ('1', 'NUM')
# ('1', 'NUM') ('by', 'ADP')
# ('by', 'ADP') ("Barnard's", 'NOUN')
# ("Barnard's", 'NOUN') ('hit-run', 'ADJ')
# ('hit-run', 'ADJ') ('car', 'NOUN')
# ('car', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('petitions', 'NOUN')
# ('petitions', 'NOUN') ('will', 'VERB')
# ('will', 'VERB') ('be', 'VERB')
# ('be', 'VERB') ('presented', 'VERB')
# ('presented', 'VERB') ('in', 'ADP')
# ('in', 'ADP') ('open', 'ADJ')
# ('open', 'ADJ') ('court', 'NOUN')
# ('court', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('President', 'NOUN')
# ('President', 'NOUN') ('Judge', 'NOUN')
# ('Judge', 'NOUN') ('William', 'NOUN')
# ('William', 'NOUN') ('F.', 'NOUN')
# ('F.', 'NOUN') ('Dannehower', 'NOUN')
# ('Dannehower', 'NOUN') (',', '.')
# (',', '.') ('Davenport', 'NOUN')
# ('Davenport', 'NOUN') ('said', 'VERB')
# ('said', 'VERB') ('.', '.')
# ('.', '.') ('Barnard', 'NOUN')
# ('Barnard', 'NOUN') (',', '.')
# (',', '.') ('who', 'PRON')
# ('who', 'PRON') ('pleaded', 'VERB')
# ('pleaded', 'VERB') ('no', 'DET')
# ('no', 'DET') ('defense', 'NOUN')
# ('defense', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('manslaughter', 'NOUN')
# ('manslaughter', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('hit-run', 'ADJ')
# ('hit-run', 'ADJ') ('charges', 'NOUN')
# ('charges', 'NOUN') (',', '.')
# (',', '.') ('was', 'VERB')
# ('was', 'VERB') ('fined', 'VERB')
# ('fined', 'VERB') ('$500', 'NOUN')
# ('$500', 'NOUN') ('by', 'ADP')
# ('by', 'ADP') ('Judge', 'NOUN')
# ('Judge', 'NOUN') ('Warren', 'NOUN')
# ('Warren', 'NOUN') ('K.', 'NOUN')
# ('K.', 'NOUN') ('Hess', 'NOUN')
# ('Hess', 'NOUN') (',', '.')
# (',', '.') ('and', 'CONJ')
# ('and', 'CONJ') ('placed', 'VERB')
# ('placed', 'VERB') ('on', 'ADP')
# ('on', 'ADP') ('two', 'NUM')
# ('two', 'NUM') ("years'", 'NOUN')
# ("years'", 'NOUN') ('probation', 'NOUN')
# ('probation', 'NOUN') ('providing', 'ADP')
# ('providing', 'ADP') ('he', 'PRON')
# ('he', 'PRON') ('does', 'VERB')
# ('does', 'VERB') ('not', 'ADV')
# ('not', 'ADV') ('drive', 'VERB')
# ('drive', 'VERB') ('during', 'ADP')
# ('during', 'ADP') ('that', 'DET')
# ('that', 'DET') ('time', 'NOUN')
# ('time', 'NOUN') ('.', '.')
# ('.', '.') ('He', 'PRON')
# ('He', 'PRON') ('was', 'VERB')
# ('was', 'VERB') ('caught', 'VERB')
# ('caught', 'VERB') ('driving', 'VERB')
# ('driving', 'VERB') ('the', 'DET')
# ('the', 'DET') ('day', 'NOUN')
# ('day', 'NOUN') ('after', 'ADP')
# ('after', 'ADP') ('the', 'DET')
# ('the', 'DET') ('sentence', 'NOUN')
# ('sentence', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('pronounced', 'VERB')
# ('pronounced', 'VERB') ('and', 'CONJ')
# ('and', 'CONJ') ('given', 'VERB')
# ('given', 'VERB') ('a', 'DET')
# ('a', 'DET') ('warning', 'NOUN')
# ('warning', 'NOUN') ('.', '.')
# ('.', '.') ('Victim', 'NOUN')
# ('Victim', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('accident', 'NOUN')
# ('accident', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('Robert', 'NOUN')
# ('Robert', 'NOUN') ('Lee', 'NOUN')
# ('Lee', 'NOUN') ('Stansbery', 'NOUN')
# ('Stansbery', 'NOUN') (',', '.')
# (',', '.') ('39', 'NUM')
# ('39', 'NUM') ('.', '.')
# ('.', '.') ('His', 'DET')
# ('His', 'DET') ('widow', 'NOUN')
# ('widow', 'NOUN') ('started', 'VERB')
# ('started', 'VERB') ('the', 'DET')
# ('the', 'DET') ('circulation', 'NOUN')
# ('circulation', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('petitions', 'NOUN')
# ('petitions', 'NOUN') ('after', 'ADP')
# ('after', 'ADP') ('Barnard', 'NOUN')
# ('Barnard', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('reprimanded', 'VERB')
# ('reprimanded', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('violating', 'VERB')
# ('violating', 'VERB') ('the', 'DET')
# ('the', 'DET') ('probation', 'NOUN')
# ('probation', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('City', 'NOUN')
# ('City', 'NOUN') ('Planning', 'VERB')
# ('Planning', 'VERB') ('Commission', 'NOUN')
# ('Commission', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('Tuesday', 'NOUN')
# ('Tuesday', 'NOUN') ('approved', 'VERB')
# ('approved', 'VERB') ('agreements', 'NOUN')
# ('agreements', 'NOUN') ('between', 'ADP')
# ('between', 'ADP') ('two', 'NUM')
# ('two', 'NUM') ('redevelopers', 'NOUN')
# ('redevelopers', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('the', 'DET')
# ('the', 'DET') ('Redevelopment', 'NOUN')
# ('Redevelopment', 'NOUN') ('Authority', 'NOUN')
# ('Authority', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('purchase', 'NOUN')
# ('purchase', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('land', 'NOUN')
# ('land', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('$300,000,000', 'NOUN')
# ('$300,000,000', 'NOUN') ('Eastwick', 'NOUN')
# ('Eastwick', 'NOUN') ('Redevelopment', 'NOUN')
# ('Redevelopment', 'NOUN') ('Area', 'NOUN')
# ('Area', 'NOUN') ('project', 'NOUN')
# ('project', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('commission', 'NOUN')
# ('commission', 'NOUN') ('also', 'ADV')
# ('also', 'ADV') ('approved', 'VERB')
# ('approved', 'VERB') ('a', 'DET')
# ('a', 'DET') ('novel', 'ADJ')
# ('novel', 'ADJ') ('plan', 'NOUN')
# ('plan', 'NOUN') ('that', 'PRON')
# ('that', 'PRON') ('would', 'VERB')
# ('would', 'VERB') ('eliminate', 'VERB')
# ('eliminate', 'VERB') ('traffic', 'NOUN')
# ('traffic', 'NOUN') ('hazards', 'NOUN')
# ('hazards', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('pedestrians', 'NOUN')
# ('pedestrians', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('project', 'NOUN')
# ('project', 'NOUN') ('.', '.')
# ('.', '.') ('One', 'NUM')
# ('One', 'NUM') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('agreements', 'NOUN')
# ('agreements', 'NOUN') ('calls', 'VERB')
# ('calls', 'VERB') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('New', 'ADJ')
# ('New', 'ADJ') ('Eastwick', 'NOUN')
# ('Eastwick', 'NOUN') ('Corp.', 'NOUN')
# ('Corp.', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('purchase', 'VERB')
# ('purchase', 'VERB') ('a', 'DET')
# ('a', 'DET') ('1311', 'NUM')
# ('1311', 'NUM') ('acre', 'NOUN')
# ('acre', 'NOUN') ('tract', 'NOUN')
# ('tract', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('$12,192,865', 'NOUN')
# ('$12,192,865', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('tract', 'NOUN')
# ('tract', 'NOUN') ('is', 'VERB')
# ('is', 'VERB') ('bounded', 'VERB')
# ('bounded', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('Island', 'NOUN')
# ('Island', 'NOUN') ('Ave.', 'NOUN')
# ('Ave.', 'NOUN') (',', '.')
# (',', '.') ('Dicks', 'NOUN')
# ('Dicks', 'NOUN') ('Ave.', 'NOUN')
# ('Ave.', 'NOUN') (',', '.')
# (',', '.') ('61st', 'ADJ')
# ('61st', 'ADJ') ('St.', 'NOUN')
# ('St.', 'NOUN') (',', '.')
# (',', '.') ('and', 'CONJ')
# ('and', 'CONJ') ('Eastwick', 'NOUN')
# ('Eastwick', 'NOUN') ('Ave.', 'NOUN')
# ('Ave.', 'NOUN') ('.', '.')
# ('.', '.') ('Four', 'NUM')
# ('Four', 'NUM') ('parks', 'NOUN')
# ('parks', 'NOUN') ('planned', 'VERB')
# ('planned', 'VERB') ('It', 'PRON')
# ('It', 'PRON') ('is', 'VERB')
# ('is', 'VERB') ('designated', 'VERB')
# ('designated', 'VERB') ('as', 'ADP')
# ('as', 'ADP') ('Stage', 'NOUN')
# ('Stage', 'NOUN') ('1', 'NUM')
# ('1', 'NUM') ('Residential', 'ADJ')
# ('Residential', 'ADJ') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Redevelopment', 'NOUN')
# ('Redevelopment', 'NOUN') ("Authority's", 'NOUN')
# ("Authority's", 'NOUN') ('master', 'ADJ')
# ('master', 'ADJ') ('plan', 'NOUN')
# ('plan', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('will', 'VERB')
# ('will', 'VERB') ('feature', 'VERB')
# ('feature', 'VERB') ('row', 'NOUN')
# ('row', 'NOUN') ('houses', 'NOUN')
# ('houses', 'NOUN') (',', '.')
# (',', '.') ('garden', 'NOUN')
# ('garden', 'NOUN') ('apartments', 'NOUN')
# ('apartments', 'NOUN') (',', '.')
# (',', '.') ('four', 'NUM')
# ('four', 'NUM') ('small', 'ADJ')
# ('small', 'ADJ') ('parks', 'NOUN')
# ('parks', 'NOUN') (',', '.')
# (',', '.') ('schools', 'NOUN')
# ('schools', 'NOUN') (',', '.')
# (',', '.') ('churches', 'NOUN')
# ('churches', 'NOUN') (',', '.')
# (',', '.') ('a', 'DET')
# ('a', 'DET') ('shopping', 'VERB')
# ('shopping', 'VERB') ('center', 'NOUN')
# ('center', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('several', 'ADJ')
# ('several', 'ADJ') ('small', 'ADJ')
# ('small', 'ADJ') ('clusters', 'NOUN')
# ('clusters', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('stores', 'NOUN')
# ('stores', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('corporation', 'NOUN')
# ('corporation', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('formed', 'VERB')
# ('formed', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Reynolds', 'NOUN')
# ('Reynolds', 'NOUN') ('Metal', 'NOUN')
# ('Metal', 'NOUN') ('Co.', 'NOUN')
# ('Co.', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('the', 'DET')
# ('the', 'DET') ('Samuel', 'NOUN')
# ('Samuel', 'NOUN') ('A.', 'NOUN')
# ('A.', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Henry', 'NOUN')
# ('Henry', 'NOUN') ('A.', 'NOUN')
# ('A.', 'NOUN') ('Berger', 'NOUN')
# ('Berger', 'NOUN') ('firm', 'NOUN')
# ('firm', 'NOUN') (',', '.')
# (',', '.') ('a', 'DET')
# ('a', 'DET') ('Philadelphia', 'NOUN')
# ('Philadelphia', 'NOUN') ('builder', 'NOUN')
# ('builder', 'NOUN') (',', '.')
# (',', '.') ('for', 'ADP')
# ('for', 'ADP') ('work', 'NOUN')
# ('work', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('project', 'NOUN')
# ('project', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('second', 'ADJ')
# ('second', 'ADJ') ('agreement', 'NOUN')
# ('agreement', 'NOUN') ('permits', 'VERB')
# ('permits', 'VERB') ('the', 'DET')
# ('the', 'DET') ('authority', 'NOUN')
# ('authority', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('sell', 'VERB')
# ('sell', 'VERB') ('a', 'DET')
# ('a', 'DET') ('520-acre', 'ADJ')
# ('520-acre', 'ADJ') ('tract', 'NOUN')
# ('tract', 'NOUN') ('west', 'NOUN')
# ('west', 'NOUN') ('of', 'ADP')
# ...
# ('who', 'PRON') ('figures', 'VERB')
# ('figures', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('be', 'VERB')
# ('be', 'VERB') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('middle', 'NOUN')
# ('middle', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('Oriole', 'NOUN')
# ('Oriole', 'NOUN') ('plans', 'NOUN')
# ('plans', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('a', 'DET')
# ('a', 'DET') ('drive', 'NOUN')
# ('drive', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('the', 'DET')
# ('the', 'DET') ('1961', 'NUM')
# ('1961', 'NUM') ('American', 'ADJ')
# ('American', 'ADJ') ('League', 'NOUN')
# ('League', 'NOUN') ('pennant', 'NOUN')
# ('pennant', 'NOUN') (',', '.')
# (',', '.') ('held', 'VERB')
# ('held', 'VERB') ('the', 'DET')
# ('the', 'DET') ("A's", 'NOUN')
# ("A's", 'NOUN') ('scoreless', 'ADJ')
# ('scoreless', 'ADJ') ('while', 'ADP')
# ('while', 'ADP') ('yielding', 'VERB')
# ('yielding', 'VERB') ('three', 'NUM')
# ('three', 'NUM') ('scattered', 'VERB')
# ('scattered', 'VERB') ('hits', 'NOUN')
# ('hits', 'NOUN') ('.', '.')
# ('.', '.') ('Then', 'ADV')
# ('Then', 'ADV') ('Dick', 'NOUN')
# ('Dick', 'NOUN') ('Hyde', 'NOUN')
# ('Hyde', 'NOUN') (',', '.')
# (',', '.') ('submarine-ball', 'NOUN')
# ('submarine-ball', 'NOUN') ('hurler', 'NOUN')
# ('hurler', 'NOUN') (',', '.')
# (',', '.') ('entered', 'VERB')
# ('entered', 'VERB') ('the', 'DET')
# ('the', 'DET') ('contest', 'NOUN')
# ('contest', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('only', 'ADJ')
# ('only', 'ADJ') ('five', 'NUM')
# ('five', 'NUM') ('batters', 'NOUN')
# ('batters', 'NOUN') ('needed', 'VERB')
# ('needed', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('face', 'VERB')
# ('face', 'VERB') ('him', 'PRON')
# ('him', 'PRON') ('before', 'ADP')
# ('before', 'ADP') ('there', 'PRT')
# ('there', 'PRT') ('existed', 'VERB')
# ('existed', 'VERB') ('a', 'DET')
# ('a', 'DET') ('3-to-3', 'NUM')
# ('3-to-3', 'NUM') ('deadlock', 'NOUN')
# ('deadlock', 'NOUN') ('.', '.')
# ('.', '.') ('A', 'DET')
# ('A', 'DET') ('two-run', 'ADJ')
# ('two-run', 'ADJ') ('homer', 'NOUN')
# ('homer', 'NOUN') ('by', 'ADP')
# ('by', 'ADP') ('Norm', 'NOUN')
# ('Norm', 'NOUN') ('Siebern', 'NOUN')
# ('Siebern', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('a', 'DET')
# ('a', 'DET') ('solo', 'NOUN')
# ('solo', 'NOUN') ('blast', 'NOUN')
# ('blast', 'NOUN') ('by', 'ADP')
# ('by', 'ADP') ('Bill', 'NOUN')
# ('Bill', 'NOUN') ('Tuttle', 'NOUN')
# ('Tuttle', 'NOUN') ('tied', 'VERB')
# ('tied', 'VERB') ('the', 'DET')
# ('the', 'DET') ('game', 'NOUN')
# ('game', 'NOUN') (',', '.')
# (',', '.') ('and', 'CONJ')
# ('and', 'CONJ') ('single', 'ADJ')
# ('single', 'ADJ') ('runs', 'NOUN')
# ('runs', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('eighth', 'ADJ')
# ('eighth', 'ADJ') ('and', 'CONJ')
# ('and', 'CONJ') ('ninth', 'ADJ')
# ('ninth', 'ADJ') ('gave', 'VERB')
# ('gave', 'VERB') ('the', 'DET')
# ('the', 'DET') ('Athletics', 'NOUN')
# ('Athletics', 'NOUN') ('their', 'DET')
# ('their', 'DET') ('fifth', 'ADJ')
# ('fifth', 'ADJ') ('victory', 'NOUN')
# ('victory', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('eight', 'NUM')
# ('eight', 'NUM') ('starts', 'NOUN')
# ('starts', 'NOUN') ('.', '.')
# ('.', '.') ('House', 'NOUN')
# ('House', 'NOUN') ('throws', 'VERB')
# ('throws', 'VERB') ('wild', 'ADV')
# ('wild', 'ADV') ('With', 'ADP')
# ('With', 'ADP') ('one', 'NUM')
# ('one', 'NUM') ('down', 'PRT')
# ('down', 'PRT') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('eighth', 'ADJ')
# ('eighth', 'ADJ') (',', '.')
# (',', '.') ('Marv', 'NOUN')
# ('Marv', 'NOUN') ('Throneberry', 'NOUN')
# ('Throneberry', 'NOUN') ('drew', 'VERB')
# ('drew', 'VERB') ('a', 'DET')
# ('a', 'DET') ('walk', 'NOUN')
# ('walk', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('stole', 'VERB')
# ('stole', 'VERB') ('second', 'ADJ')
# ('second', 'ADJ') ('as', 'ADP')
# ('as', 'ADP') ('Hyde', 'NOUN')
# ('Hyde', 'NOUN') ('fanned', 'VERB')
# ('fanned', 'VERB') ('Tuttle', 'NOUN')
# ('Tuttle', 'NOUN') ('.', '.')
# ('.', '.') ('Catcher', 'NOUN')
# ('Catcher', 'NOUN') ('Frank', 'NOUN')
# ('Frank', 'NOUN') ("House's", 'NOUN')
# ("House's", 'NOUN') ('throw', 'NOUN')
# ('throw', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('an', 'DET')
# ('an', 'DET') ('effort', 'NOUN')
# ('effort', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('nab', 'VERB')
# ('nab', 'VERB') ('Throneberry', 'NOUN')
# ('Throneberry', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('wide', 'ADV')
# ('wide', 'ADV') ('and', 'CONJ')
# ('and', 'CONJ') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('dirt', 'NOUN')
# ('dirt', 'NOUN') ('.', '.')
# ('.', '.') ('Then', 'ADV')
# ('Then', 'ADV') ('Heywood', 'NOUN')
# ('Heywood', 'NOUN') ('Sullivan', 'NOUN')
# ('Sullivan', 'NOUN') (',', '.')
# (',', '.') ('Kansas', 'NOUN')
# ('Kansas', 'NOUN') ('City', 'NOUN')
# ('City', 'NOUN') ('catcher', 'NOUN')
# ('catcher', 'NOUN') (',', '.')
# (',', '.') ('singled', 'VERB')
# ('singled', 'VERB') ('up', 'ADP')
# ('up', 'ADP') ('the', 'DET')
# ('the', 'DET') ('middle', 'NOUN')
# ('middle', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Throneberry', 'NOUN')
# ('Throneberry', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('across', 'PRT')
# ('across', 'PRT') ('with', 'ADP')
# ('with', 'ADP') ('what', 'DET')
# ('what', 'DET') ('proved', 'VERB')
# ('proved', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('be', 'VERB')
# ('be', 'VERB') ('the', 'DET')
# ('the', 'DET') ('winning', 'VERB')
# ('winning', 'VERB') ('run', 'NOUN')
# ('run', 'NOUN') ('.', '.')
# ('.', '.') ('Rookie', 'NOUN')
# ('Rookie', 'NOUN') ('southpaw', 'NOUN')
# ('southpaw', 'NOUN') ('George', 'NOUN')
# ('George', 'NOUN') ('Stepanovich', 'NOUN')
# ('Stepanovich', 'NOUN') ('relieved', 'VERB')
# ('relieved', 'VERB') ('Hyde', 'NOUN')
# ('Hyde', 'NOUN') ('at', 'ADP')
# ('at', 'ADP') ('the', 'DET')
# ('the', 'DET') ('start', 'NOUN')
# ('start', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('ninth', 'ADJ')
# ('ninth', 'ADJ') ('and', 'CONJ')
# ('and', 'CONJ') ('gave', 'VERB')
# ('gave', 'VERB') ('up', 'PRT')
# ('up', 'PRT') ('the', 'DET')
# ('the', 'DET') ("A's", 'NOUN')
# ("A's", 'NOUN') ('fifth', 'ADJ')
# ('fifth', 'ADJ') ('tally', 'NOUN')
# ('tally', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('a', 'DET')
# ('a', 'DET') ('walk', 'NOUN')
# ('walk', 'NOUN') ('to', 'ADP')
# ('to', 'ADP') ('second', 'ADJ')
# ('second', 'ADJ') ('baseman', 'NOUN')
# ('baseman', 'NOUN') ('Dick', 'NOUN')
# ('Dick', 'NOUN') ('Howser', 'NOUN')
# ('Howser', 'NOUN') (',', '.')
# (',', '.') ('a', 'DET')
# ('a', 'DET') ('wild', 'ADJ')
# ('wild', 'ADJ') ('pitch', 'NOUN')
# ('pitch', 'NOUN') (',', '.')
# (',', '.') ('and', 'CONJ')
# ('and', 'CONJ') ('Frank', 'NOUN')
# ('Frank', 'NOUN') ("Cipriani's", 'NOUN')
# ("Cipriani's", 'NOUN') ('single', 'NOUN')
# ('single', 'NOUN') ('under', 'ADP')
# ('under', 'ADP') ('Shortstop', 'NOUN')
# ('Shortstop', 'NOUN') ('Jerry', 'NOUN')
# ('Jerry', 'NOUN') ("Adair's", 'NOUN')
# ("Adair's", 'NOUN') ('glove', 'NOUN')
# ('glove', 'NOUN') ('into', 'ADP')
# ('into', 'ADP') ('center', 'NOUN')
# ('center', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('Orioles', 'NOUN')
# ('Orioles', 'NOUN') ('once', 'ADV')
# ('once', 'ADV') ('again', 'ADV')
# ('again', 'ADV') ('performed', 'VERB')
# ('performed', 'VERB') ('at', 'ADP')
# ('at', 'ADP') ('the', 'DET')
# ('the', 'DET') ('plate', 'NOUN')
# ('plate', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('powderpuff', 'NOUN')
# ('powderpuff', 'NOUN') ('fashion', 'NOUN')
# ('fashion', 'NOUN') (',', '.')
# (',', '.') ('gathering', 'VERB')
# ('gathering', 'VERB') ('only', 'ADJ')
# ('only', 'ADJ') ('seven', 'NUM')
# ('seven', 'NUM') ('blows', 'NOUN')
# ('blows', 'NOUN') ('off', 'ADP')
# ('off', 'ADP') ('the', 'DET')
# ('the', 'DET') ('offerings', 'NOUN')
# ('offerings', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('three', 'NUM')
# ('three', 'NUM') ('Kansas', 'NOUN')
# ('Kansas', 'NOUN') ('City', 'NOUN')
# ('City', 'NOUN') ('pitchers', 'NOUN')
# ('pitchers', 'NOUN') ('.', '.')
# ('.', '.') ('Three', 'NUM')
# ('Three', 'NUM') ('were', 'VERB')
# ('were', 'VERB') ('doubles', 'NOUN')
# ('doubles', 'NOUN') (',', '.')
# (',', '.') ('Brooks', 'NOUN')
# ('Brooks', 'NOUN') ('Robinson', 'NOUN')
# ('Robinson', 'NOUN') ('getting', 'VERB')
# ('getting', 'VERB') ('a', 'DET')
# ('a', 'DET') ('pair', 'NOUN')
# ('pair', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Marv', 'NOUN')
# ('Marv', 'NOUN') ('Breeding', 'NOUN')
# ('Breeding', 'NOUN') ('one', 'NUM')
# ('one', 'NUM') ('.', '.')
# ('.', '.') ('Hartman', 'NOUN')
# ('Hartman', 'NOUN') ('impressive', 'ADJ')
# ('impressive', 'ADJ') ('Bill', 'NOUN')
# ('Bill', 'NOUN') ('Kunkel', 'NOUN')
# ('Kunkel', 'NOUN') (',', '.')
# (',', '.') ('Bob', 'NOUN')
# ('Bob', 'NOUN') ('Hartman', 'NOUN')
# ('Hartman', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('Ed', 'NOUN')
# ('Ed', 'NOUN') ('Keegan', 'NOUN')
# ('Keegan', 'NOUN') ('did', 'VERB')
# ('did', 'VERB') ('the', 'DET')
# ('the', 'DET') ('mound', 'NOUN')
# ('mound', 'NOUN') ('chores', 'NOUN')
# ('chores', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('the', 'DET')
# ('the', 'DET') ('club', 'NOUN')
# ('club', 'NOUN') ('down', 'PRT')
# ('down', 'PRT') ('from', 'ADP')
# ('from', 'ADP') ('West', 'ADJ')
# ('West', 'ADJ') ('Palm', 'NOUN')
# ('Palm', 'NOUN') ('Beach', 'NOUN')
# ('Beach', 'NOUN') ('to', 'PRT')
# ('to', 'PRT') ('play', 'VERB')
# ('play', 'VERB') ('the', 'DET')
# ('the', 'DET') ('game', 'NOUN')
# ('game', 'NOUN') ('before', 'ADP')
# ('before', 'ADP') ('767', 'NUM')
# ('767', 'NUM') ('paying', 'VERB')
# ('paying', 'VERB') ('customers', 'NOUN')
# ('customers', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('Miami', 'NOUN')
# ('Miami', 'NOUN') ('Stadium', 'NOUN')
# ('Stadium', 'NOUN') ('.', '.')
# ('.', '.') ('The', 'DET')
# ('The', 'DET') ('Birds', 'NOUN')
# ('Birds', 'NOUN') ('got', 'VERB')
# ('got', 'VERB') ('five', 'NUM')
# ('five', 'NUM') ('hits', 'NOUN')
# ('hits', 'NOUN') ('and', 'CONJ')
# ('and', 'CONJ') ('all', 'PRT')
# ('all', 'PRT') ('three', 'NUM')
# ('three', 'NUM') ('of', 'ADP')
# ('of', 'ADP') ('their', 'DET')
# ('their', 'DET') ('runs', 'NOUN')
# ('runs', 'NOUN') ('off', 'ADP')
# ('off', 'ADP') ('Kunkel', 'NOUN')
# ('Kunkel', 'NOUN') ('before', 'ADP')
# ('before', 'ADP') ('Hartman', 'NOUN')
# ('Hartman', 'NOUN') ('took', 'VERB')
# ('took', 'VERB') ('over', 'PRT')
# ('over', 'PRT') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('top', 'NOUN')
# ('top', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('fourth', 'ADJ')
# ('fourth', 'ADJ') ('.', '.')
# ('.', '.') ('Hartman', 'NOUN')
# ('Hartman', 'NOUN') (',', '.')
# (',', '.') ('purchased', 'VERB')
# ('purchased', 'VERB') ('by', 'ADP')
# ('by', 'ADP') ('the', 'DET')
# ('the', 'DET') ("A's", 'NOUN')
# ("A's", 'NOUN') ('from', 'ADP')
# ('from', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Milwaukee', 'NOUN')
# ('Milwaukee', 'NOUN') ('Braves', 'NOUN')
# ('Braves', 'NOUN') ('last', 'ADJ')
# ('last', 'ADJ') ('fall', 'NOUN')
# ('fall', 'NOUN') (',', '.')
# (',', '.') ('allowed', 'VERB')
# ('allowed', 'VERB') ('no', 'DET')
# ('no', 'DET') ('hits', 'NOUN')
# ('hits', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('his', 'DET')
# ('his', 'DET') ('scoreless', 'ADJ')
# ('scoreless', 'ADJ') ('three-inning', 'ADJ')
# ('three-inning', 'ADJ') ('appearance', 'NOUN')
# ('appearance', 'NOUN') (',', '.')
# (',', '.') ('and', 'CONJ')
# ('and', 'CONJ') ('merited', 'VERB')
# ('merited', 'VERB') ('the', 'DET')
# ('the', 'DET') ('triumph', 'NOUN')
# ('triumph', 'NOUN') ('.', '.')
# ('.', '.') ('Keegan', 'NOUN')
# ('Keegan', 'NOUN') (',', '.')
# (',', '.') ('a', 'DET')
# ('a', 'DET') ('6-foot-3-inch', 'ADJ')
# ('6-foot-3-inch', 'ADJ') ('158-pounder', 'NOUN')
# ('158-pounder', 'NOUN') (',', '.')
# (',', '.') ('gave', 'VERB')
# ('gave', 'VERB') ('up', 'PRT')
# ('up', 'PRT') ('the', 'DET')
# ('the', 'DET') ("Orioles'", 'NOUN')
# ("Orioles'", 'NOUN') ('last', 'ADJ')
# ('last', 'ADJ') ('two', 'NUM')
# ('two', 'NUM') ('safeties', 'NOUN')
# ('safeties', 'NOUN') ('over', 'ADP')
# ('over', 'ADP') ('the', 'DET')
# ('the', 'DET') ('final', 'ADJ')
# ('final', 'ADJ') ('three', 'NUM')
# ('three', 'NUM') ('frames', 'NOUN')
# ('frames', 'NOUN') (',', '.')
# (',', '.') ('escaping', 'VERB')
# ('escaping', 'VERB') ('a', 'DET')
# ('a', 'DET') ('load', 'NOUN')
# ('load', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('trouble', 'NOUN')
# ('trouble', 'NOUN') ('in', 'ADP')
# ('in', 'ADP') ('the', 'DET')
# ('the', 'DET') ('ninth', 'ADJ')
# ('ninth', 'ADJ') ('when', 'ADV')
# ('when', 'ADV') ('the', 'DET')
# ('the', 'DET') ('Birds', 'NOUN')
# ('Birds', 'NOUN') ('threatened', 'VERB')
# ('threatened', 'VERB') ('but', 'CONJ')
# ('but', 'CONJ') ('failed', 'VERB')
# ('failed', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('tally', 'VERB')
# ('tally', 'VERB') ('.', '.')
# ('.', '.') ('Robinson', 'NOUN')
# ('Robinson', 'NOUN') ('doubles', 'VERB')
# ('doubles', 'VERB') ('again', 'ADV')
# ('again', 'ADV') ('In', 'ADP')
# ('In', 'ADP') ('the', 'DET')
# ('the', 'DET') ('ninth', 'ADJ')
# ('ninth', 'ADJ') (',', '.')
# (',', '.') ('Robinson', 'NOUN')
# ('Robinson', 'NOUN') ('led', 'VERB')
# ('led', 'VERB') ('off', 'PRT')
# ('off', 'PRT') ('with', 'ADP')
# ('with', 'ADP') ('his', 'DET')
# ('his', 'DET') ('second', 'ADJ')
# ('second', 'ADJ') ('double', 'NOUN')
# ('double', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('night', 'NOUN')
# ('night', 'NOUN') (',', '.')
# (',', '.') ('a', 'DET')
# ('a', 'DET') ('blast', 'NOUN')
# ('blast', 'NOUN') ('off', 'ADP')
# ('off', 'ADP') ('the', 'DET')
# ('the', 'DET') ('fence', 'NOUN')
# ('fence', 'NOUN') ('375', 'NUM')
# ('375', 'NUM') ('feet', 'NOUN')
# ('feet', 'NOUN') ('deep', 'ADV')
# ('deep', 'ADV') ('into', 'ADP')
# ('into', 'ADP') ('left', 'NOUN')
# ('left', 'NOUN') ('.', '.')
# ('.', '.') ('Whitey', 'NOUN')
# ('Whitey', 'NOUN') ('Herzog', 'NOUN')
# ('Herzog', 'NOUN') (',', '.')
# (',', '.') ('performing', 'VERB')
# ('performing', 'VERB') ('in', 'ADP')
# ('in', 'ADP') ('right', 'NOUN')
# ('right', 'NOUN') ('as', 'ADP')
# ('as', 'ADP') ('the', 'DET')
# ('the', 'DET') ('Orioles', 'NOUN')
# ('Orioles', 'NOUN') ('fielded', 'VERB')
# ('fielded', 'VERB') ('possibly', 'ADV')
# ('possibly', 'ADV') ('their', 'DET')
# ('their', 'DET') ('strongest', 'ADJ')
# ('strongest', 'ADJ') ('team', 'NOUN')
# ('team', 'NOUN') ('of', 'ADP')
# ('of', 'ADP') ('the', 'DET')
# ('the', 'DET') ('spring', 'NOUN')
# ('spring', 'NOUN') (',', '.')
# (',', '.') ('worked', 'VERB')
# ('worked', 'VERB') ('Keegan', 'NOUN')
# ('Keegan', 'NOUN') ('for', 'ADP')
# ('for', 'ADP') ('a', 'DET')
# ('a', 'DET') ('base', 'NOUN')
# ('base', 'NOUN') ('on', 'ADP')
# ('on', 'ADP') ('balls', 'NOUN')
# ('balls', 'NOUN') ('.', '.')
# ('.', '.') ('Then', 'ADV')
# ('Then', 'ADV') ('three', 'NUM')
# ('three', 'NUM') ('consecutive', 'ADJ')
# ('consecutive', 'ADJ') ('pinch-hitters', 'NOUN')
# ('pinch-hitters', 'NOUN') ('failed', 'VERB')
# ('failed', 'VERB') ('to', 'PRT')
# ('to', 'PRT') ('produce', 'VERB')
# ('produce', 'VERB') ('.', '.')
# ('.', '.') ('Pete', 'NOUN')
# ('Pete', 'NOUN') ('Ward', 'NOUN')
# ('Ward', 'NOUN') ('was', 'VERB')
# ('was', 'VERB') ('sent', 'VERB')
# ('sent', 'VERB') ('in', 'PRT')
# ('in', 'PRT') ('for', 'ADP')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-292078c6c363> in <module>()
#       1 word_tag_pairs = nltk.bigrams(brown_news_tagged)
#       2 for (a,b) in word_tag_pairs:
# ----> 3   print(a,b)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
noun_preceders = [a[1] for (a, b) in word_tag_pairs if b[1] ==
'NOUN']
fdist = nltk.FreqDist(noun_preceders)
[tag for (tag, _) in fdist.most_common()]
# Out:
# ['NOUN',
#  'DET',
#  'ADJ',
#  'ADP',
#  '.',
#  'VERB',
#  'CONJ',
#  'NUM',
#  'ADV',
#  'PRT',
#  'PRON',
#  'X']

# %%
#Verb

wsj = nltk.corpus.treebank.tagged_words(tagset='universal')
word_tag_fd = nltk.FreqDist(wsj)
[wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# ['is',
#  'said',
#  'was',
#  'are',
#  'be',
#  'has',
#  'have',
#  'will',
#  'says',
#  'would',
#  'were',
#  'had',
#  'been',
#  'could',
#  "'s",
#  'can',
#  'do',
#  'say',
#  'make',
#  'may',
#  'did',
#  'rose',
#  'made',
#  'does',
#  'expected',
#  'buy',
#  'take',
#  'get',
#  'might',
#  'sell',
#  'added',
#  'sold',
#  'help',
#  'including',
#  'should',
#  'reported',
#  'according',
#  'pay',
#  'compared',
#  'being',
#  'fell',
#  'began',
#  'based',
#  'used',
#  'closed',
#  "'re",
#  'want',
#  'see',
#  'took',
#  'yield',
#  'offered',
#  'set',
#  'priced',
#  'approved',
#  'come',
#  'noted',
#  'cut',
#  'ended',
#  'found',
#  'increased',
#  'become',
#  'think',
#  'named',
#  'go',
#  'trying',
#  'proposed',
#  'received',
#  'growing',
#  'declined',
#  'held',
#  'give',
#  'came',
#  'use',
#  'put',
#  'making',
#  'continue',
#  'raise',
#  'estimated',
#  'called',
#  'paid',
#  'designed',
#  'going',
#  'expects',
#  'seeking',
#  'must',
#  'plans',
#  'wo',
#  'increasing',
#  'saying',
#  'got',
#  'owns',
#  'trading',
#  'acquired',
#  'gained',
#  'fined',
#  'reached',
#  'holding',
#  'announced',
#  'filed',
#  'became',
#  'seek',
#  'included',
#  'using',
#  'led',
#  'decided',
#  'keep',
#  'disclosed',
#  'agreed',
#  'find',
#  'failed',
#  'run',
#  'taken',
#  'know',
#  'coming',
#  "'ve",
#  'completed',
#  'built',
#  'raised',
#  'traded',
#  'lost',
#  'continued',
#  'paying',
#  'include',
#  'believe',
#  'receive',
#  'posted',
#  'wants',
#  'scheduled',
#  'went',
#  'indicated',
#  'provide',
#  'helped',
#  'needed',
#  'goes',
#  'told',
#  'result',
#  'need',
#  'caused',
#  'continues',
#  'dropped',
#  'showed',
#  'ordered',
#  'changed',
#  'face',
#  'continuing',
#  'launched',
#  'gives',
#  'reduce',
#  "'m",
#  'lead',
#  'planned',
#  'wanted',
#  'following',
#  'remains',
#  'followed',
#  'remain',
#  'meet',
#  'believes',
#  'trade',
#  'includes',
#  'improve',
#  'buying',
#  'issued',
#  'rise',
#  'leading',
#  'ca',
#  'involved',
#  'known',
#  'like',
#  'makes',
#  'having',
#  'rejected',
#  'rising',
#  'increase',
#  'turned',
#  'operating',
#  'read',
#  'feel',
#  'win',
#  'given',
#  'prevent',
#  'offset',
#  'barred',
#  'earned',
#  'consented',
#  'support',
#  'gave',
#  'totaled',
#  'acquire',
#  'required',
#  'begin',
#  'require',
#  'offer',
#  'preferred',
#  'produced',
#  'bought',
#  'offering',
#  'asked',
#  'carry',
#  'build',
#  'takes',
#  'seem',
#  'introduced',
#  'taking',
#  'won',
#  'aimed',
#  'hurt',
#  'adds',
#  'cited',
#  'sought',
#  'bring',
#  'remaining',
#  'considered',
#  'suspended',
#  'prove',
#  'looking',
#  'doing',
#  'involving',
#  'opened',
#  'working',
#  'close',
#  'own',
#  'report',
#  'left',
#  'boosted',
#  'giving',
#  'fixed',
#  'listed',
#  'runs',
#  'purchasing',
#  'consider',
#  'prepared',
#  'hit',
#  'getting',
#  'alleged',
#  'look',
#  'allowed',
#  'approve',
#  'wrote',
#  'reduced',
#  'fall',
#  'advanced',
#  'appears',
#  'mixed',
#  'described',
#  'expect',
#  'manufacturing',
#  'spent',
#  'According',
#  'hopes',
#  'underlying',
#  'produce',
#  'work',
#  'placed',
#  'allow',
#  'sells',
#  'operate',
#  'extend',
#  'surged',
#  'jumped',
#  'boost',
#  'slowing',
#  'provided',
#  'seems',
#  'ending',
#  'selling',
#  'opposed',
#  'created',
#  'move',
#  'seen',
#  'comment',
#  'valued',
#  'losing',
#  'mature',
#  'provides',
#  'let',
#  'stopped',
#  'worked',
#  'thought',
#  'watch',
#  'introduce',
#  'related',
#  'improved',
#  'raising',
#  'seemed',
#  'force',
#  'beginning',
#  'leave',
#  'believed',
#  'stand',
#  'developed',
#  'decline',
#  'expire',
#  'managing',
#  'hold',
#  'invested',
#  'suggests',
#  'represent',
#  'settle',
#  'change',
#  'contributed',
#  'indicates',
#  'asking',
#  'elaborate',
#  'shows',
#  'refused',
#  'quoted',
#  'comes',
#  'ease',
#  'passed',
#  'Says',
#  'avoid',
#  'threatened',
#  'cause',
#  'end',
#  'violate',
#  'operates',
#  'kept',
#  "'ll",
#  'soared',
#  'eliminated',
#  'becomes',
#  'create',
#  'print',
#  'shall',
#  'show',
#  'replaced',
#  'owned',
#  'argue',
#  'beat',
#  'elected',
#  'complete',
#  'issue',
#  'act',
#  'return',
#  'registered',
#  'suffer',
#  'worried',
#  'succeed',
#  'block',
#  'contain',
#  'occur',
#  'pursue',
#  'combined',
#  'requires',
#  'met',
#  'brought',
#  'started',
#  'covered',
#  'turn',
#  'running',
#  'eliminate',
#  'file',
#  'plunged',
#  'fallen',
#  'ran',
#  'fired',
#  'becoming',
#  'contained',
#  'managed',
#  'Take',
#  'suggested',
#  'accused',
#  'appeared',
#  'slow',
#  'helping',
#  'discovered',
#  'add',
#  'referred',
#  'oppose',
#  'stop',
#  'claim',
#  'sent',
#  'formed',
#  'resulting',
#  'turning',
#  'limited',
#  'shipped',
#  'forced',
#  'send',
#  'attract',
#  'admitting',
#  'denying',
#  'disgorge',
#  'attributed',
#  'causing',
#  'studied',
#  'resigned',
#  'cutting',
#  'voted',
#  'settled',
#  'expand',
#  'stood',
#  'retired',
#  'moved',
#  'pending',
#  'providing',
#  'anticipated',
#  'decide',
#  'creating',
#  'prompted',
#  'developing',
#  'start',
#  'maintained',
#  'expanding',
#  'follows',
#  'ranged',
#  'focused',
#  'climbed',
#  'reflect',
#  'insist',
#  'owed',
#  'happen',
#  'adjusted',
#  'awarded',
#  'reporting',
#  'talk',
#  'offers',
#  'written',
#  'urged',
#  'carried',
#  'identified',
#  'confirmed',
#  'playing',
#  'thinking',
#  'calls',
#  'means',
#  'tried',
#  'lying',
#  'asks',
#  'building',
#  'suggest',
#  'falling',
#  'discuss',
#  'matched',
#  'concluded',
#  'keeping',
#  "'d",
#  'returned',
#  'withdrawn',
#  'bid',
#  'saw',
#  'signed',
#  'financing',
#  'assuming',
#  'adopted',
#  'attempting',
#  'accepted',
#  'cover',
#  'facing',
#  'risk',
#  'expanded',
#  'leaving',
#  'raises',
#  'declared',
#  'exercise',
#  'finished',
#  'regarding',
#  'finance',
#  'charge',
#  'starting',
#  'realize',
#  'felt',
#  'remained',
#  'expressed',
#  'done',
#  'replace',
#  'veto',
#  'stay',
#  'delivered',
#  'join',
#  'publishing',
#  'enters',
#  'appear',
#  'talking',
#  'heard',
#  'dumped',
#  'imported',
#  'assume',
#  'declining',
#  'capture',
#  'grew',
#  'holds',
#  'lift',
#  'treat',
#  'receiving',
#  'joined',
#  'reflecting',
#  'released',
#  'maintaining',
#  'cost',
#  'lowered',
#  'costs',
#  'exceed',
#  'gaining',
#  'considering',
#  'determined',
#  'ruled',
#  'hope',
#  'located',
#  'tied',
#  'heads',
#  'applied',
#  'failing',
#  'showing',
#  'apply',
#  'protecting',
#  'tells',
#  'complained',
#  'ask',
#  'triggered',
#  'entered',
#  'total',
#  'producing',
#  'denied',
#  'reducing',
#  'reflects',
#  'account',
#  'predicting',
#  'intended',
#  'purchased',
#  'blamed',
#  'worry',
#  'broken',
#  'carries',
#  'learned',
#  'renewed',
#  'walk',
#  'viewed',
#  'die',
#  'speculated',
#  'needs',
#  'gets',
#  'wait',
#  'caught',
#  'claims',
#  'choose',
#  'fail',
#  'insists',
#  'knows',
#  'pass',
#  'grown',
#  'gotten',
#  'grows',
#  'responded',
#  'play',
#  'try',
#  'mean',
#  'encourage',
#  'chosen',
#  'admits',
#  'Do',
#  'dismissed',
#  'realized',
#  'serve',
#  'associated',
#  'slipped',
#  'argued',
#  'citing',
#  'seeks',
#  'preventing',
#  'sparked',
#  'review',
#  'opening',
#  'fueled',
#  'negotiate',
#  'drop',
#  'pleased',
#  'spend',
#  'care',
#  'represents',
#  'spread',
#  'explains',
#  'push',
#  'divided',
#  'proposing',
#  'gain',
#  'representing',
#  'financed',
#  'execute',
#  'existing',
#  'discussed',
#  'uses',
#  'live',
#  'ring',
#  'signal',
#  'focus',
#  'hired',
#  'limit',
#  'begins',
#  'reflected',
#  'hear',
#  'determine',
#  'profit',
#  'marketed',
#  'warned',
#  'qualified',
#  'died',
#  'surviving',
#  'study',
#  'explained',
#  'imposed',
#  'recognize',
#  'eased',
#  'indicate',
#  'permit',
#  'retain',
#  'yielding',
#  'boosts',
#  'obtain',
#  'employs',
#  'banned',
#  'pointed',
#  'leaves',
#  'withdraw',
#  'refund',
#  'collected',
#  'upheld',
#  'benefited',
#  'doubled',
#  'attached',
#  'jump',
#  'compete',
#  'incurred',
#  'removed',
#  'honor',
#  'varying',
#  'marketing',
#  'protect',
#  'reach',
#  'share',
#  'requested',
#  'grant',
#  'stepping',
#  'direct',
#  'curb',
#  'controlling',
#  'snapped',
#  'tend',
#  'cast',
#  'clear',
#  'permitted',
#  'remove',
#  'revive',
#  'draw',
#  'predicted',
#  'suspect',
#  'coupled',
#  'belong',
#  'call',
#  'describes',
#  'played',
#  'committed',
#  'advertising',
#  'tested',
#  'revived',
#  'earns',
#  'feeling',
#  'turns',
#  'executed',
#  'killed',
#  'presented',
#  'deserve',
#  'mention',
#  'seeing',
#  'discussing',
#  'convicted',
#  'telling',
#  'agree',
#  'denies',
#  'pursued',
#  'spurred',
#  'accommodate',
#  'surrendered',
#  'gone',
#  'teach',
#  'booming',
#  'serving',
#  'restore',
#  'restructured',
#  'taught',
#  'feared',
#  'meant',
#  'adding',
#  'publishes',
#  'improving',
#  'ignoring',
#  'represented',
#  'funded',
#  'involve',
#  'charged',
#  'fared',
#  'eliminates',
#  'tumbled',
#  'redeemed',
#  'resolve',
#  'stem',
#  'hire',
#  'obtained',
#  'develop',
#  'employed',
#  'prohibits',
#  'promote',
#  'impose',
#  'consist',
#  'investigating',
#  'accepting',
#  'plan',
#  'insisted',
#  'contacted',
#  'note',
#  'driving',
#  'contends',
#  'cites',
#  'point',
#  'sign',
#  'printed',
#  'advertise',
#  'breaks',
#  'damaged',
#  'check',
#  'thinks',
#  'looming',
#  'expecting',
#  'exercised',
#  'auctioned',
#  'disappointed',
#  'subordinated',
#  'respond',
#  'secured',
#  'integrated',
#  'performed',
#  'targeting',
#  'stepped',
#  'moving',
#  'split',
#  'Buy',
#  'stemming',
#  'executing',
#  'shut',
#  'writing',
#  'regulated',
#  'stands',
#  'attend',
#  'reopen',
#  'drawn',
#  'Put',
#  'notes',
#  'weaken',
#  'trailed',
#  'deliver',
#  'occurred',
#  'changing',
#  'accept',
#  'expelled',
#  'amounted',
#  'scrutinizing',
#  'suspend',
#  'compares',
#  'backed',
#  'vote',
#  'covers',
#  'knew',
#  'joining',
#  'record',
#  'regarded',
#  'copy',
#  'conclude',
#  'ought',
#  'dominated',
#  'pushed',
#  'closing',
#  'rumored',
#  'respected',
#  'specified',
#  'understand',
#  'supported',
#  'perform',
#  'declaring',
#  'struggling',
#  'abandoned',
#  'considers',
#  'warning',
#  'offsetting',
#  'break',
#  'follow',
#  'figure',
#  'increases',
#  'proving',
#  'edged',
#  'Buying',
#  'forecast',
#  'specify',
#  'extended',
#  'tendered',
#  'unveiled',
#  'treating',
#  'exposed',
#  'industrialized',
#  'regulate',
#  'contracted',
#  'blip',
#  'vary',
#  'slid',
#  'succeeds',
#  'lifted',
#  'acts',
#  'welcomed',
#  'squeezed',
#  'fed',
#  'casting',
#  'prolonged',
#  'recorded',
#  'announce',
#  'reward',
#  'bowed',
#  'justify',
#  'asserted',
#  'appealing',
#  'faces',
#  'rule',
#  'inched',
#  'manufacture',
#  'fund',
#  'anticipates',
#  'link',
#  'describe',
#  'roll',
#  'calculate',
#  'transferring',
#  'favored',
#  'claiming',
#  'hurting',
#  'investing',
#  'trained',
#  'instituted',
#  'introducing',
#  'vowed',
#  'deemed',
#  'pose',
#  'concerned',
#  'accelerated',
#  'feels',
#  'solved',
#  'forgiven',
#  'stored',
#  'assembled',
#  'totaling',
#  'linked',
#  'forces',
#  'attempts',
#  'advertised',
#  'marks',
#  'sweeping',
#  'invest',
#  'kicked',
#  'brings',
#  'scrambled',
#  'diversify',
#  'swing',
#  'skyrocketed',
#  'targeted',
#  'repaid',
#  'open',
#  'crippled',
#  'lent',
#  'belongs',
#  'stressed',
#  'leveling',
#  'manufactured',
#  'pick',
#  'cite',
#  'provoke',
#  'last',
#  'climbing',
#  'Excluding',
#  'adjusting',
#  'counts',
#  'handle',
#  'polled',
#  'drink',
#  'sets',
#  'sidestep',
#  'fare',
#  'letting',
#  'entering',
#  'ban',
#  'visiting',
#  'endorsed',
#  'balked',
#  'compensate',
#  'terminated',
#  'modify',
#  'operated',
#  'entitles',
#  'romanticized',
#  'spends',
#  'condemned',
#  'competing',
#  'returning',
#  'murdered',
#  'load',
#  'lives',
#  'recommend',
#  'fighting',
#  'fills',
#  'charges',
#  'exist',
#  'Stung',
#  'banning',
#  'admitted',
#  'talks',
#  'launch',
#  'attracted',
#  'featured',
#  'devote',
#  'featuring',
#  'suing',
#  'shrinks',
#  'tripled',
#  'pumping',
#  'contributing',
#  'spur',
#  'concentrated',
#  'export',
#  'pull',
#  'approach',
#  'step',
#  'regard',
#  'breach',
#  'pleaded',
#  'inspired',
#  'defended',
#  'treated',
#  'casts',
#  'violated',
#  'enforce',
#  'surfaced',
#  'concentrate',
#  'stressing',
#  'suffered',
#  'loved',
#  'advised',
#  'studying',
#  'pushing',
#  'earn',
#  'save',
#  'interviewed',
#  'explain',
#  'gauge',
#  'measured',
#  'deny',
#  'hampered',
#  'fill',
#  'nominated',
#  'assured',
#  'finding',
#  'conducting',
#  'tracks',
#  'merge',
#  'merged',
#  'banking',
#  'achieve',
#  'acquiring',
#  'post',
#  'wish',
#  'retained',
#  'spark',
#  'chaired',
#  'deal',
#  'submit',
#  'sending',
#  'test',
#  'relegated',
#  'alleging',
#  'mounted',
#  'harass',
#  'crossing',
#  'involves',
#  'assist',
#  'killing',
#  'served',
#  'understood',
#  'touch',
#  'Asked',
#  'design',
#  'retaining',
#  'belonging',
#  'compiled',
#  'Guaranteed',
#  'positioned',
#  'plunging',
#  'locked',
#  'starts',
#  'waiting',
#  'rolled',
#  'lock',
#  'drifted',
#  'measures',
#  'Estimated',
#  ...]

# %% [markdown]
# #Korean Pos Tagging - Konlpy

# %%
pip install JPype1-py3
# Out:
# Collecting JPype1-py3
#   Downloading JPype1-py3-0.5.5.4.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 4.7 MB/s
# Building wheels for collected packages: JPype1-py3
#   Building wheel for JPype1-py3 (setup.py) ... done
#   Created wheel for JPype1-py3: filename=JPype1_py3-0.5.5.4-cp37-cp37m-linux_x86_64.whl size=2679613 sha256=2dbe474148445ba169122559e6b04ebc814d185b48bbc714edfe78079738fcb8
#   Stored in directory: /root/.cache/pip/wheels/e7/d1/09/f55dca0203b0691945bdf0f63d486a0b4d4e5ec4bd78a2502e
# Successfully built JPype1-py3
# Installing collected packages: JPype1-py3
# Successfully installed JPype1-py3-0.5.5.4

# %%
pip install Konlpy
# Out:
# Collecting Konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 133 kB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 74.9 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from Konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.2 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from Konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from Konlpy) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->Konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->Konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->Konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->Konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->Konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->Konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->Konlpy) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->Konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->Konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->Konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, Konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 Konlpy-0.5.2 beautifulsoup4-4.6.0 colorama-0.4.4

# %%
from konlpy.tag import Okt
okt = Okt()
print(okt.morphs(u'단독입찰보다 복수입찰의 경우'))
# Out:
# ['단독', '입찰', '보다', '복수', '입찰', '의', '경우']

# %%
print(okt.nouns(u'유일하게 항공기 체계 종합개발 경험을 갖고 있는 KAI는'))
# Out:
# ['항공기', '체계', '종합', '개발', '경험']

# %%
 print(okt.phrases(u'날카로운 분석과 신뢰감 있는 진행으로'))
# Out:
# ['날카로운 분석', '날카로운 분석과 신뢰감', '날카로운 분석과 신뢰감 있는 진행', '분석', '신뢰', '진행']

# %%
print(okt.pos(u'이것도 되나욬ㅋㅋ'))
# Out:
# [('이', 'Determiner'), ('것', 'Noun'), ('도', 'Josa'), ('되나욬', 'Noun'), ('ㅋㅋ', 'KoreanParticle')]

# %%
from konlpy.tag import Okt
okt = Okt()
korea=u'아시아 대륙의 동쪽 끝 한반도에 있는 나라로서, 최초의 국가인 고조선은 BC 108년까지 존재했다. 고구려, 백제, 신라의 삼국시대를 거쳐 중세에는 고려가 세워졌으며, 이후 조선이 건립되어 근대까지 이어졌다. 현대 들어 35년의 일제강점기를 거쳐 제2차 세계대전 뒤 미국과 소련 군대의 한반도 분할 주둔으로 남북으로 나뉘었고 1948년 대한민국이 수립되었다. 이후 6·25전쟁이 일어나 휴전중이며, 현재까지 분단국가로 남아 있다'
sentences = korea.split(".")
for sentence in sentences:
 tagged = okt.pos(sentence, norm=True, stem=True)
 print(tagged)
# Out:
# [('아시아', 'Noun'), ('대륙', 'Noun'), ('의', 'Josa'), ('동쪽', 'Noun'), ('끝', 'Noun'), ('한반도', 'Noun'), ('에', 'Josa'), ('있다', 'Adjective'), ('나라', 'Noun'), ('로서', 'Noun'), (',', 'Punctuation'), ('최초', 'Noun'), ('의', 'Josa'), ('국가', 'Noun'), ('인', 'Josa'), ('고조선', 'Noun'), ('은', 'Josa'), ('BC', 'Alpha'), ('108년', 'Number'), ('까지', 'Foreign'), ('존재', 'Noun'), ('하다', 'Verb')]
# [('고구려', 'Noun'), (',', 'Punctuation'), ('백제', 'Noun'), (',', 'Punctuation'), ('신라', 'Noun'), ('의', 'Josa'), ('삼국시대', 'Noun'), ('를', 'Josa'), ('거치다', 'Verb'), ('중세', 'Noun'), ('에는', 'Josa'), ('고려', 'Noun'), ('가', 'Josa'), ('세워지다', 'Verb'), (',', 'Punctuation'), ('이후', 'Noun'), ('조선', 'Noun'), ('이', 'Josa'), ('건립', 'Noun'), ('되어다', 'Verb'), ('근대', 'Noun'), ('까지', 'Josa'), ('이어지다', 'Verb')]
# [('현대', 'Noun'), ('들다', 'Verb'), ('35년', 'Number'), ('의', 'Foreign'), ('일제강점기', 'Noun'), ('를', 'Josa'), ('거치다', 'Verb'), ('제', 'Noun'), ('2', 'Number'), ('차', 'Noun'), ('세계대전', 'Noun'), ('뒤', 'Noun'), ('미국', 'Noun'), ('과', 'Josa'), ('소련', 'Noun'), ('군대', 'Noun'), ('의', 'Josa'), ('한반도', 'Noun'), ('분할', 'Noun'), ('주둔', 'Noun'), ('으로', 'Josa'), ('남북', 'Noun'), ('으로', 'Josa'), ('나뉘다', 'Verb'), ('1948년', 'Number'), ('대한민국', 'Noun'), ('이', 'Josa'), ('수립', 'Noun'), ('되어다', 'Verb')]
# [('이후', 'Noun'), ('6', 'Number'), ('·', 'Punctuation'), ('25', 'Number'), ('전쟁', 'Noun'), ('이', 'Josa'), ('일어나다', 'Verb'), ('휴전', 'Noun'), ('중', 'Suffix'), ('이며', 'Josa'), (',', 'Punctuation'), ('현재', 'Noun'), ('까지', 'Josa'), ('분단국가', 'Noun'), ('로', 'Josa'), ('남아', 'Noun'), ('있다', 'Adjective')]

# %%
# %tensorflow_version 1.x
from keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) =imdb.load_data(num_words=10000)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# 17465344/17464789 [==============================] - 3s 0us/step
# /tensorflow-1.15.2/python3.7/keras/datasets/imdb.py:101: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /tensorflow-1.15.2/python3.7/keras/datasets/imdb.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
len(train_data[0])
# Out:
# 218

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1. # set specific indices of results[i] to 1s
  return results
# vectorized training/test data
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)
# train_labels and test_labels are lists of 0s and 1s
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
